# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Mobile Price Classification/train.csv")
csv_original_encode = csv

#dataread.hash_encoding(csv_original_encode,["blue","dual_sim","fc","four_g","mobile_wt","n_cores","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"])
dataread.label_encoding(csv,"blue")
dataread.label_encoding(csv,"dual_sim")
dataread.label_encoding(csv,"fc")
dataread.label_encoding(csv,"four_g")
dataread.label_encoding(csv,"mobile_wt")
dataread.label_encoding(csv,"n_cores")
dataread.label_encoding(csv,"sc_h")
dataread.label_encoding(csv,"sc_w")
dataread.label_encoding(csv,"talk_time")
dataread.label_encoding(csv,"three_g")
dataread.label_encoding(csv,"touch_screen")
dataread.label_encoding(csv,"wifi")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"price_range")
# Out:
# continuous_feature_num 8
# discrete_feature_num 12
# self.data_discrete_indexes ['blue', 'dual_sim', 'fc', 'four_g', 'm_dep', 'n_cores', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi']

# %%
import experiment 
scope_num = 30 
topology_ratio = 2

experiment = experiment.Experiment() 
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# self.random_dic {1: 117, 0: 1346, 3: 160, 2: 80}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.23
# recall_score_fcg 0.23102371029712698
# precision_score_fcg 0.22902063003075623
# f1_score_fcg 0.22618041241027093
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# self.random_dic {1: 306, 0: 1014, 3: 566, 2: 1197}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25479744743425825
# precision_score_fcg 0.2519274977990441
# f1_score_fcg 0.24891990011214807
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# self.random_dic {1: 217, 0: 603, 3: 1276, 2: 26}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.24
# recall_score_fcg 0.24142543196140243
# precision_score_fcg 0.24203570193341106
# f1_score_fcg 0.23708890334087296
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# self.random_dic {1: 376, 0: 1358, 3: 999, 2: 245}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.24833333333333332
# recall_score_fcg 0.24519279256418014
# precision_score_fcg 0.24517713764263335
# f1_score_fcg 0.2424304764341658
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# self.random_dic {1: 1054, 0: 408, 3: 599, 2: 1173}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.22166666666666668
# recall_score_fcg 0.22519637936475403
# precision_score_fcg 0.2257821521775171
# f1_score_fcg 0.22011147993112332
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# self.random_dic {1: 1233, 0: 560, 3: 407, 2: 281}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.24833333333333332
# recall_score_fcg 0.24519279256418014
# precision_score_fcg 0.24517713764263335
# f1_score_fcg 0.2424304764341658
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# self.random_dic {1: 1382, 0: 855, 3: 1146, 2: 377}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.22
# recall_score_fcg 0.2232956190606324
# precision_score_fcg 0.22309348452756625
# f1_score_fcg 0.21813072771976882
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# self.random_dic {1: 1057, 0: 1396, 3: 916, 2: 801}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.27666666666666667
# recall_score_fcg 0.27773162110372607
# precision_score_fcg 0.2762330533545997
# f1_score_fcg 0.2722137368595931
# Experiment number: 9
# self.random_dic {1: 750, 0: 600, 3: 164, 2: 466}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.27166666666666667
# recall_score_fcg 0.26933618976045703
# precision_score_fcg 0.2673834958324758
# f1_score_fcg 0.26467364157581547
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# self.random_dic {1: 285, 0: 19, 3: 1188, 2: 143}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.24833333333333332
# recall_score_fcg 0.24519279256418014
# precision_score_fcg 0.24517713764263335
# f1_score_fcg 0.2424304764341658
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# self.random_dic {1: 115, 0: 536, 3: 878, 2: 1190}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23151313370876808
# precision_score_fcg 0.23411318093857905
# f1_score_fcg 0.2270594885381747
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# self.random_dic {1: 1362, 0: 1156, 3: 1070, 2: 1107}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.26
# recall_score_fcg 0.26149138517195497
# precision_score_fcg 0.26766583273307265
# f1_score_fcg 0.25933219801640855
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# self.random_dic {1: 1034, 0: 319, 3: 798, 2: 157}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.255
# recall_score_fcg 0.2559753576227239
# precision_score_fcg 0.2498053708324758
# f1_score_fcg 0.24874676023797523
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# self.random_dic {1: 1016, 0: 839, 3: 485, 2: 804}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.27666666666666667
# recall_score_fcg 0.27773162110372607
# precision_score_fcg 0.2762330533545997
# f1_score_fcg 0.2722137368595931
# Experiment number: 15
# self.random_dic {1: 488, 0: 79, 3: 787, 2: 735}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.275
# recall_score_fcg 0.2721809252156147
# precision_score_fcg 0.2680572378766628
# f1_score_fcg 0.23507188069695392
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# self.random_dic {1: 885, 0: 419, 3: 1398, 2: 801}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.255
# recall_score_fcg 0.2559753576227239
# precision_score_fcg 0.2498053708324758
# f1_score_fcg 0.24874676023797523
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# self.random_dic {1: 200, 0: 616, 3: 201, 2: 1361}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.25333333333333335
# recall_score_fcg 0.24161016032429233
# precision_score_fcg 0.2423241000467508
# f1_score_fcg 0.21302399069564848
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# self.random_dic {1: 340, 0: 977, 3: 301, 2: 274}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.23
# recall_score_fcg 0.24192400537450753
# precision_score_fcg 0.2320601704279825
# f1_score_fcg 0.20113628433669462
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# self.random_dic {1: 14, 0: 207, 3: 1247, 2: 1099}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.265
# recall_score_fcg 0.2609305917488947
# precision_score_fcg 0.2370874771558502
# f1_score_fcg 0.22208041112999485
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# self.random_dic {1: 952, 0: 187, 3: 1144, 2: 530}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25479744743425825
# precision_score_fcg 0.2519274977990441
# f1_score_fcg 0.24891990011214807
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# self.random_dic {1: 893, 0: 730, 3: 372, 2: 713}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.245
# recall_score_fcg 0.2460518760349668
# precision_score_fcg 0.24956917897201072
# f1_score_fcg 0.2428132300018421
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# self.random_dic {1: 115, 0: 504, 3: 1161, 2: 25}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23151313370876808
# precision_score_fcg 0.23411318093857905
# f1_score_fcg 0.2270594885381747
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# self.random_dic {1: 688, 0: 695, 3: 48, 2: 303}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.26
# recall_score_fcg 0.26149138517195497
# precision_score_fcg 0.26766583273307265
# f1_score_fcg 0.25933219801640855
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# self.random_dic {1: 1342, 0: 820, 3: 624, 2: 399}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.27666666666666667
# recall_score_fcg 0.27773162110372607
# precision_score_fcg 0.2762330533545997
# f1_score_fcg 0.2722137368595931
# Experiment number: 25
# self.random_dic {1: 875, 0: 876, 3: 1247, 2: 274}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.245
# recall_score_fcg 0.2443957257699828
# precision_score_fcg 0.2389124258963893
# f1_score_fcg 0.23801140918154604
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# self.random_dic {1: 1353, 0: 1038, 3: 197, 2: 15}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23151313370876808
# precision_score_fcg 0.23411318093857905
# f1_score_fcg 0.2270594885381747
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# self.random_dic {1: 618, 0: 350, 3: 890, 2: 196}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.255
# recall_score_fcg 0.2526874570966598
# precision_score_fcg 0.25138603943712695
# f1_score_fcg 0.24920534516704432
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# self.random_dic {1: 1158, 0: 880, 3: 587, 2: 1135}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23151313370876808
# precision_score_fcg 0.23411318093857905
# f1_score_fcg 0.2270594885381747
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# self.random_dic {1: 632, 0: 1298, 3: 273, 2: 1278}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.235
# recall_score_fcg 0.22356961077113774
# precision_score_fcg 0.21904511453950443
# f1_score_fcg 0.1927419688900775
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# self.random_dic {1: 461, 0: 187, 3: 1161, 2: 139}
# accuracy_score_baseline 0.27166666666666667
# recall_score_baseline 0.27535831405733024
# precision_score_baseline 0.2755508071621816
# f1_score_baseline 0.26493939439983255
# accuracy_score_fcg 0.22833333333333333
# recall_score_fcg 0.23151313370876808
# precision_score_fcg 0.23411318093857905
# f1_score_fcg 0.2270594885381747
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.27666666666666667
# max_recall_score_fcg 0.27773162110372607
# max_precision_score_fcg 0.2762330533545997
# max_f1_score_fcg 0.2722137368595931
# all_accuracy_score_baseline mean 0.2716666666666666
# all_recall_score_baseline mean 0.27535831405733024
# all_precision_score_baseline mean 0.2755508071621816
# all_f1_score_baseline mean 0.2649393943998326
# all_accuracy_score_fcg mean 0.24811111111111114
# all_recall_score_fcg mean 0.24814983242619543
# all_precision_score_fcg mean 0.24664503630892617
# all_f1_score_fcg mean 0.23844991614609556
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 0.059024956077337265
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.271667  5.646013e-17  1.030816e-17
# 1       all_accuracy_score_fcg  30.0  0.248111  1.753340e-02  3.201147e-03
# 2                     combined  60.0  0.259889  1.709304e-02  2.206702e-03
#
#    95% Conf.  Interval
# 0   0.271667  0.271667
# 1   0.241564  0.254658
# 2   0.255473  0.264304
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  2.360000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   7.358500e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.899900e+00
# 7                                       Hedge's g =   1.875300e+00
# 8                                  Glass's delta1 =   4.172069e+14
# 9                                Point-Biserial r =   6.949000e-01
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 0.09725265949964523
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline  30.0  0.275358  0.000000  0.000000        NaN
# 1       all_recall_score_fcg  30.0  0.248150  0.016609  0.003032   0.241948
# 2                   combined  60.0  0.261754  0.017995  0.002323   0.257106
#
#    Interval
# 0       NaN
# 1  0.254352
# 2  0.266403
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.0272
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    8.9727
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.3167
# 7                                       Hedge's g =    2.2867
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7624
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 0.07225675135850906
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_baseline  30.0  0.275551  0.000000  0.000000
# 1       all_precision_score_fcg  30.0  0.246645  0.016362  0.002987
# 2                      combined  60.0  0.261098  0.018547  0.002394
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.240536  0.252755
# 2   0.256307  0.265889
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...   0.0289
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    9.6766
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.4985
# 7                                       Hedge's g =    2.4660
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7858
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 0.5394185781478882
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.264939  5.646013e-17  1.030816e-17
# 1       all_f1_score_fcg  30.0  0.238450  1.995788e-02  3.643793e-03
# 2               combined  60.0  0.251695  1.934371e-02  2.497263e-03
#
#    95% Conf.  Interval
# 0   0.264939  0.264939
# 1   0.230998  0.245902
# 2   0.246698  0.256692
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  2.650000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   7.269800e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.877000e+00
# 7                                       Hedge's g =   1.852700e+00
# 8                                  Glass's delta1 =   4.691714e+14
# 9                                Point-Biserial r =   6.905000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment_M
scope_num = 2
topology_ratio =2


dic= {0: 180, 2: 17, 1: 121, 3: 75}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
