# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("student_data.csv")
#csv = csv.drop(columns=['CLIENTNUM'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"school")
dataread.label_encoding(csv,"sex")
dataread.label_encoding(csv,"address")
dataread.label_encoding(csv,"famsize")
dataread.label_encoding(csv,"Pstatus")
dataread.label_encoding(csv,"Mjob")
dataread.label_encoding(csv,"Fjob")
dataread.label_encoding(csv,"reason")
dataread.label_encoding(csv,"guardian")
dataread.label_encoding(csv,"schoolsup")
dataread.label_encoding(csv,"famsup")
dataread.label_encoding(csv,"paid")
dataread.label_encoding(csv,"activities")
dataread.label_encoding(csv,"nursery")
dataread.label_encoding(csv,"higher")
dataread.label_encoding(csv,"internet")
dataread.label_encoding(csv,"romantic")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"reason")
# Out:
# continuous_feature_num 1
# discrete_feature_num 31
# self.data_discrete_indexes ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'G1', 'G2', 'G3']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)

# %%
import experiment
scope_num = 30
topology_ratio =4

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio,nfolder =5)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.3474576271186441
# recall_score_baseline 0.26145690834473323
# precision_score_baseline 0.258553747285115
# f1_score_baseline 0.25153489068583407
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 2
# accuracy_score_baseline 0.3474576271186441
# recall_score_baseline 0.28981825288254837
# precision_score_baseline 0.28499278499278496
# f1_score_baseline 0.27683429325927106
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.3045241352354895
# precision_score_baseline 0.2881602353585112
# f1_score_baseline 0.2879955997880526
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.27462380300957595
# precision_score_baseline 0.26851409460105113
# f1_score_baseline 0.2633234028467395
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 5
# accuracy_score_baseline 0.3728813559322034
# recall_score_baseline 0.2819767441860465
# precision_score_baseline 0.27880089899524063
# f1_score_baseline 0.27154558404558404
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.2746238030095759
# precision_score_baseline 0.27884615384615385
# f1_score_baseline 0.2619579081632653
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 7
# accuracy_score_baseline 0.3474576271186441
# recall_score_baseline 0.25991792065663477
# precision_score_baseline 0.2610469652051802
# f1_score_baseline 0.2473155929038282
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 8
# accuracy_score_baseline 0.3474576271186441
# recall_score_baseline 0.25991792065663477
# precision_score_baseline 0.2618472509776858
# f1_score_baseline 0.24416959406713507
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 9
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.26727086183310533
# precision_score_baseline 0.2586080586080586
# f1_score_baseline 0.2533159463487332
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 10
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.2715458276333789
# precision_score_baseline 0.2668740573152338
# f1_score_baseline 0.254989604989605
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 11
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.27308481532147744
# precision_score_baseline 0.2790285145888594
# f1_score_baseline 0.2610582010582011
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 12
# accuracy_score_baseline 0.3305084745762712
# recall_score_baseline 0.2452120383036936
# precision_score_baseline 0.2406832298136646
# f1_score_baseline 0.22962662337662337
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 13
# accuracy_score_baseline 0.3305084745762712
# recall_score_baseline 0.24982900136798908
# precision_score_baseline 0.243730407523511
# f1_score_baseline 0.24182775420399183
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 14
# accuracy_score_baseline 0.3220338983050847
# recall_score_baseline 0.24093707250342
# precision_score_baseline 0.24143173023770037
# f1_score_baseline 0.22870572050899918
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 15
# accuracy_score_baseline 0.3474576271186441
# recall_score_baseline 0.2645348837209302
# precision_score_baseline 0.25947511441647597
# f1_score_baseline 0.2571610845295056
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 16
# accuracy_score_baseline 0.3813559322033898
# recall_score_baseline 0.2877906976744186
# precision_score_baseline 0.2878871128871129
# f1_score_baseline 0.27126520176893315
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# accuracy_score_baseline 0.3389830508474576
# recall_score_baseline 0.28092632401797923
# precision_score_baseline 0.2689393939393939
# f1_score_baseline 0.26382766822501086
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_baseline 0.3474576271186441
# recall_score_baseline 0.25991792065663477
# precision_score_baseline 0.25661671400084596
# f1_score_baseline 0.24599771297884504
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 19
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.27462380300957595
# precision_score_baseline 0.27370183270676696
# f1_score_baseline 0.26341715917429365
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 20
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.27308481532147744
# precision_score_baseline 0.2820638188368503
# f1_score_baseline 0.2599257884972171
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.2746238030095759
# precision_score_baseline 0.2665447579240683
# f1_score_baseline 0.2592317213876847
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 22
# accuracy_score_baseline 0.3728813559322034
# recall_score_baseline 0.280437756497948
# precision_score_baseline 0.27947761194029846
# f1_score_baseline 0.26423063543599257
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 23
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.26727086183310533
# precision_score_baseline 0.261002886002886
# f1_score_baseline 0.25257529537642
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 24
# accuracy_score_baseline 0.3813559322033898
# recall_score_baseline 0.2877906976744186
# precision_score_baseline 0.2895698051948052
# f1_score_baseline 0.27247669363463056
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.29871018174711744
# precision_score_baseline 0.2905237722048067
# f1_score_baseline 0.28879213814238563
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.26727086183310533
# precision_score_baseline 0.26660462382445144
# f1_score_baseline 0.2532182903742537
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Experiment number: 27
# accuracy_score_baseline 0.3644067796610169
# recall_score_baseline 0.27462380300957595
# precision_score_baseline 0.27229712211563395
# f1_score_baseline 0.26332734351602277
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good accuracy result !!!!!
# Experiment number: 28
# accuracy_score_baseline 0.3813559322033898
# recall_score_baseline 0.31615204221223375
# precision_score_baseline 0.31929590017825316
# f1_score_baseline 0.30362334338885005
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# accuracy_score_baseline 0.3728813559322034
# recall_score_baseline 0.2819767441860465
# precision_score_baseline 0.2860243055555555
# f1_score_baseline 0.2716009166067577
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# accuracy_score_baseline 0.3389830508474576
# recall_score_baseline 0.25872093023255816
# precision_score_baseline 0.2574712643678161
# f1_score_baseline 0.2515064939329754
# accuracy_score_fcg 0.3813559322033898
# recall_score_fcg 0.28317373461012313
# precision_score_fcg 0.2802579365079365
# f1_score_fcg 0.25890603085554
# all_accuracy_score_baseline mean 0.35706214689265536
# all_recall_score_baseline mean 0.27343984105270014
# all_precision_score_baseline mean 0.27095380551482573
# all_f1_score_baseline mean 0.26054594010718807
# all_accuracy_score_fcg mean 0.38135593220338976
# all_recall_score_fcg mean 0.28317373461012324
# all_precision_score_fcg mean 0.28025793650793657
# all_f1_score_fcg mean 0.25890603085554
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.357062  1.537605e-02  2.807270e-03
# 1       all_accuracy_score_fcg  30.0  0.381356  5.646013e-17  1.030816e-17
# 2                     combined  60.0  0.369209  1.631734e-02  2.106560e-03
#
#    95% Conf.  Interval
# 0   0.351321  0.362804
# 1   0.381356  0.381356
# 2   0.364994  0.373424
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0243
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -8.6539
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.2344
# 7                                       Hedge's g =   -2.2054
# 8                                  Glass's delta1 =   -1.5800
# 9                                Point-Biserial r =   -0.7507
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.273440  1.648810e-02  3.010302e-03
# 1       all_recall_score_fcg  30.0  0.283174  1.129203e-16  2.061632e-17
# 2                   combined  60.0  0.278307  1.255840e-02  1.621283e-03
#
#    95% Conf.  Interval
# 0   0.267283  0.279597
# 1   0.283174  0.283174
# 2   0.275063  0.281551
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0097
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -3.2335
# 3                           Two side test p value =    0.0020
# 4                          Difference < 0 p value =    0.0010
# 5                          Difference > 0 p value =    0.9990
# 6                                       Cohen's d =   -0.8349
# 7                                       Hedge's g =   -0.8241
# 8                                  Glass's delta1 =   -0.5904
# 9                                Point-Biserial r =   -0.3908
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.270954  1.678194e-02  3.063948e-03
# 1       all_precision_score_fcg  30.0  0.280258  5.646013e-17  1.030816e-17
# 2                      combined  60.0  0.275606  1.266643e-02  1.635229e-03
#
#    95% Conf.  Interval
# 0   0.264687  0.277220
# 1   0.280258  0.280258
# 2   0.272334  0.278878
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0093
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -3.0366
# 3                           Two side test p value =    0.0036
# 4                          Difference < 0 p value =    0.0018
# 5                          Difference > 0 p value =    0.9982
# 6                                       Cohen's d =   -0.7841
# 7                                       Hedge's g =   -0.7739
# 8                                  Glass's delta1 =   -0.5544
# 9                                Point-Biserial r =   -0.3704
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.260546  0.016162  0.002951   0.254511
# 1       all_f1_score_fcg  30.0  0.258906  0.000000  0.000000        NaN
# 2               combined  60.0  0.259726  0.011361  0.001467   0.256791
#
#    Interval
# 0  0.266581
# 1       NaN
# 2  0.262661
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0016
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    0.5558
# 3                           Two side test p value =    0.5805
# 4                          Difference < 0 p value =    0.7097
# 5                          Difference > 0 p value =    0.2903
# 6                                       Cohen's d =    0.1435
# 7                                       Hedge's g =    0.1416
# 8                                  Glass's delta1 =    0.1015
# 9                                Point-Biserial r =    0.0728
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
