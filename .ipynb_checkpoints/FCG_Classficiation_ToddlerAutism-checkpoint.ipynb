# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")
csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Ethnicity")
dataread.label_encoding(csv,"Jaundice")
dataread.label_encoding(csv,"Family_mem_with_ASD")
dataread.label_encoding(csv,"Who completed the test")
dataread.label_encoding(csv,"Class/ASD Traits ")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Class/ASD Traits ")
# Out:
# continuous_feature_num 2
# discrete_feature_num 16
# self.data_discrete_indexes ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'Qchat-10-Score', 'Sex', 'Ethnicity', 'Jaundice', 'Family_mem_with_ASD', 'Who completed the test']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# self.random_dic {1: 31, 0: 5}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.967741935483871
# recall_score_fcg 0.9772727272727273
# precision_score_fcg 0.95
# f1_score_fcg 0.9620563035495717
# Not good precision_score_ !!!!!
# Experiment number: 2
# self.random_dic {1: 56, 0: 33}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.967741935483871
# recall_score_fcg 0.9772727272727273
# precision_score_fcg 0.95
# f1_score_fcg 0.9620563035495717
# Not good precision_score_ !!!!!
# Experiment number: 3
# self.random_dic {1: 36, 0: 22}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# self.random_dic {1: 3, 0: 41}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# self.random_dic {1: 69, 0: 14}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.967741935483871
# recall_score_fcg 0.9772727272727273
# precision_score_fcg 0.95
# f1_score_fcg 0.9620563035495717
# Not good precision_score_ !!!!!
# Experiment number: 6
# self.random_dic {1: 72, 0: 64}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# self.random_dic {1: 25, 0: 18}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.967741935483871
# recall_score_fcg 0.9772727272727273
# precision_score_fcg 0.95
# f1_score_fcg 0.9620563035495717
# Not good precision_score_ !!!!!
# Experiment number: 8
# self.random_dic {1: 9, 0: 67}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# self.random_dic {1: 36, 0: 18}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# self.random_dic {1: 53, 0: 5}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.967741935483871
# recall_score_fcg 0.9772727272727273
# precision_score_fcg 0.95
# f1_score_fcg 0.9620563035495717
# Not good precision_score_ !!!!!
# Experiment number: 11
# self.random_dic {1: 55, 0: 27}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# self.random_dic {1: 37, 0: 39}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# self.random_dic {1: 35, 0: 22}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# self.random_dic {1: 49, 0: 41}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# self.random_dic {1: 3, 0: 33}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.967741935483871
# recall_score_fcg 0.9772727272727273
# precision_score_fcg 0.95
# f1_score_fcg 0.9620563035495717
# Not good precision_score_ !!!!!
# Experiment number: 16
# self.random_dic {1: 49, 0: 2}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# self.random_dic {1: 44, 0: 18}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# self.random_dic {1: 8, 0: 18}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# self.random_dic {1: 49, 0: 2}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# self.random_dic {1: 24, 0: 39}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# self.random_dic {1: 72, 0: 5}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# self.random_dic {1: 53, 0: 14}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# self.random_dic {1: 23, 0: 41}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# self.random_dic {1: 42, 0: 33}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.967741935483871
# recall_score_fcg 0.9772727272727273
# precision_score_fcg 0.95
# f1_score_fcg 0.9620563035495717
# Not good precision_score_ !!!!!
# Experiment number: 25
# self.random_dic {1: 55, 0: 34}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# self.random_dic {1: 6, 0: 22}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# self.random_dic {1: 65, 0: 64}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# self.random_dic {1: 38, 0: 64}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# self.random_dic {1: 72, 0: 5}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# self.random_dic {1: 24, 0: 41}
# accuracy_score_baseline 0.967741935483871
# recall_score_baseline 0.9444444444444444
# precision_score_baseline 0.9782608695652174
# f1_score_baseline 0.9594771241830065
# accuracy_score_fcg 0.9354838709677419
# recall_score_fcg 0.9545454545454546
# precision_score_fcg 0.9090909090909092
# f1_score_fcg 0.9261904761904762
# Not good accuracy result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.967741935483871
# max_recall_score_fcg 0.9772727272727273
# max_precision_score_fcg 0.95
# max_f1_score_fcg 0.9620563035495717
# all_accuracy_score_baseline mean 0.9677419354838712
# all_recall_score_baseline mean 0.9444444444444441
# all_precision_score_baseline mean 0.9782608695652176
# all_f1_score_baseline mean 0.9594771241830065
# all_accuracy_score_fcg mean 0.9430107526881718
# all_recall_score_fcg mean 0.9598484848484846
# all_precision_score_fcg mean 0.918636363636364
# all_f1_score_fcg mean 0.9345591692409321
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 1.0146386841825006e-08
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.967742  2.258405e-16  4.123265e-17
# 1       all_accuracy_score_fcg  30.0  0.943011  1.387687e-02  2.533559e-03
# 2                     combined  60.0  0.955376  1.581617e-02  2.041859e-03
#
#    95% Conf.  Interval
# 0   0.967742  0.967742
# 1   0.937829  0.948192
# 2   0.951291  0.959462
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  2.470000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   9.761400e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   2.520400e+00
# 7                                       Hedge's g =   2.487700e+00
# 8                                  Glass's delta1 =   1.095073e+14
# 9                                Point-Biserial r =   7.884000e-01
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 1.0146386841825006e-08
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.944444  3.387608e-16  6.184897e-17
# 1       all_recall_score_fcg  30.0  0.959848  9.776888e-03  1.785007e-03
# 2                   combined  60.0  0.952146  1.035907e-02  1.337350e-03
#
#    95% Conf.  Interval
# 0   0.944444  0.944444
# 1   0.956198  0.963499
# 2   0.949470  0.954822
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -1.540000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -8.629700e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.228200e+00
# 7                                       Hedge's g =  -2.199200e+00
# 8                                  Glass's delta1 =  -4.547174e+13
# 9                                Point-Biserial r =  -7.498000e-01
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 1.0146386841825006e-08
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.978261  2.258405e-16  4.123265e-17
# 1       all_precision_score_fcg  30.0  0.918636  1.759840e-02  3.213013e-03
# 2                      combined  60.0  0.948449  3.249710e-02  4.195358e-03
#
#    95% Conf.  Interval
# 0   0.978261  0.978261
# 1   0.912065  0.925208
# 2   0.940054  0.956844
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all...  5.960000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   1.855720e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   4.791400e+00
# 7                                       Hedge's g =   4.729200e+00
# 8                                  Glass's delta1 =   2.640116e+14
# 9                                Point-Biserial r =   9.251000e-01
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 1.0146386841825006e-08
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.959477  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  30.0  0.934559  0.015429  0.002817   0.928798
# 2               combined  60.0  0.947018  0.016579  0.002140   0.942735
#
#    Interval
# 0       NaN
# 1  0.940320
# 2  0.951301
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0249
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    8.8458
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.2840
# 7                                       Hedge's g =    2.2543
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7578
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment_M
scope_num = 2
topology_ratio =2


dic= {0: 180, 2: 17, 1: 121, 3: 75}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
