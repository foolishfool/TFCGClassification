# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("drug200.csv")
#csv = csv.drop(columns=['ID'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"BP")
dataread.label_encoding(csv,"Cholesterol")
dataread.label_encoding(csv,"Drug")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Drug")
# Out:
# continuous_feature_num 2
# discrete_feature_num 3
# self.data_discrete_indexes ['Sex', 'BP', 'Cholesterol']

# %%
import experiment
scope_num = 30
topology_ratio =2


experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio,nfolder = 0)
# Out:
# Experiment number: 1
# key 3, choosen_index  36
# key 0, choosen_index  129
# key 4, choosen_index  52
# key 1, choosen_index  131
# key 2, choosen_index  89
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5302134646962233
# precision_score_fcg 0.3759774436090225
# f1_score_fcg 0.39103668261562996
# Not good accuracy result !!!!!
# Experiment number: 2
# key 3, choosen_index  0
# key 0, choosen_index  44
# key 4, choosen_index  45
# key 1, choosen_index  51
# key 2, choosen_index  41
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.35
# recall_score_fcg 0.47733990147783256
# precision_score_fcg 0.2835964912280701
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_fcg 0.296704698809962
# Not good accuracy result !!!!!
# Experiment number: 3
# key 3, choosen_index  74
# key 0, choosen_index  11
# key 4, choosen_index  52
# key 1, choosen_index  98
# key 2, choosen_index  31
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.4
# recall_score_fcg 0.49802955665024634
# precision_score_fcg 0.2985964912280702
# f1_score_fcg 0.333676615781879
# Not good accuracy result !!!!!
# Experiment number: 4
# key 3, choosen_index  136
# key 0, choosen_index  86
# key 4, choosen_index  83
# key 1, choosen_index  101
# key 2, choosen_index  41
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.31666666666666665
# recall_score_fcg 0.5095238095238095
# precision_score_fcg 0.2435964912280702
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_fcg 0.30858054226475284
# Not good accuracy result !!!!!
# Experiment number: 5
# key 3, choosen_index  74
# key 0, choosen_index  88
# key 4, choosen_index  28
# key 1, choosen_index  29
# key 2, choosen_index  53
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.26666666666666666
# recall_score_fcg 0.2942528735632184
# precision_score_fcg 0.2926923076923077
# f1_score_fcg 0.2501048416837891
# Not good accuracy result !!!!!
# Experiment number: 6
# key 3, choosen_index  74
# key 0, choosen_index  84
# key 4, choosen_index  113
# key 1, choosen_index  98
# key 2, choosen_index  99
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5080459770114942
# precision_score_fcg 0.38499999999999995
# f1_score_fcg 0.3973377889167363
# Not good accuracy result !!!!!
# Experiment number: 7
# key 3, choosen_index  0
# key 0, choosen_index  86
# key 4, choosen_index  112
# key 1, choosen_index  51
# key 2, choosen_index  25
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.31666666666666665
# recall_score_fcg 0.36091954022988504
# precision_score_fcg 0.3226923076923077
# f1_score_fcg 0.3000898040898041
# Not good accuracy result !!!!!
# Experiment number: 8
# key 3, choosen_index  5
# key 0, choosen_index  11
# key 4, choosen_index  52
# key 1, choosen_index  57
# key 2, choosen_index  108
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.46781609195402296
# precision_score_fcg 0.3207875457875458
# f1_score_fcg 0.31498575498575504
# Not good accuracy result !!!!!
# Experiment number: 9
# key 3, choosen_index  136
# key 0, choosen_index  71
# key 4, choosen_index  79
# key 1, choosen_index  107
# key 2, choosen_index  53
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.31666666666666665
# recall_score_fcg 0.5333333333333333
# precision_score_fcg 0.26078754578754576
# f1_score_fcg 0.3208465608465609
# Not good accuracy result !!!!!
# Experiment number: 10
# key 3, choosen_index  5
# key 0, choosen_index  104
# key 4, choosen_index  76
# key 1, choosen_index  123
# key 2, choosen_index  49
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5080459770114942
# precision_score_fcg 0.38499999999999995
# f1_score_fcg 0.3973377889167363
# Not good accuracy result !!!!!
# Experiment number: 11
# key 3, choosen_index  36
# key 0, choosen_index  18
# key 4, choosen_index  119
# key 1, choosen_index  118
# key 2, choosen_index  97
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.26666666666666666
# recall_score_fcg 0.2942528735632184
# precision_score_fcg 0.2926923076923077
# f1_score_fcg 0.2501048416837891
# Not good accuracy result !!!!!
# Experiment number: 12
# key 3, choosen_index  0
# key 0, choosen_index  82
# key 4, choosen_index  30
# key 1, choosen_index  107
# key 2, choosen_index  53
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.5747126436781609
# precision_score_fcg 0.41500000000000004
# f1_score_fcg 0.44732275132275134
# Not good accuracy result !!!!!
# Experiment number: 13
# key 3, choosen_index  74
# key 0, choosen_index  114
# key 4, choosen_index  38
# key 1, choosen_index  123
# key 2, choosen_index  25
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.3
# recall_score_fcg 0.4344827586206897
# precision_score_fcg 0.2707875457875458
# f1_score_fcg 0.258985754985755
# Not good accuracy result !!!!!
# Experiment number: 14
# key 3, choosen_index  74
# key 0, choosen_index  10
# key 4, choosen_index  128
# key 1, choosen_index  107
# key 2, choosen_index  41
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.26666666666666666
# recall_score_fcg 0.2942528735632184
# precision_score_fcg 0.2926923076923077
# f1_score_fcg 0.2501048416837891
# Not good accuracy result !!!!!
# Experiment number: 15
# key 3, choosen_index  36
# key 0, choosen_index  40
# key 4, choosen_index  137
# key 1, choosen_index  73
# key 2, choosen_index  108
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.59688013136289
# precision_score_fcg 0.40597744360902255
# f1_score_fcg 0.441021645021645
# Not good accuracy result !!!!!
# Experiment number: 16
# key 3, choosen_index  111
# key 0, choosen_index  27
# key 4, choosen_index  3
# key 1, choosen_index  107
# key 2, choosen_index  89
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5302134646962233
# precision_score_fcg 0.3759774436090225
# f1_score_fcg 0.39103668261562996
# Not good accuracy result !!!!!
# Experiment number: 17
# key 3, choosen_index  136
# key 0, choosen_index  110
# key 4, choosen_index  109
# key 1, choosen_index  123
# key 2, choosen_index  99
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.25
# recall_score_fcg 0.4302134646962233
# precision_score_fcg 0.30880952380952376
# f1_score_fcg 0.26049122807017544
# Not good accuracy result !!!!!
# Experiment number: 18
# key 3, choosen_index  42
# key 0, choosen_index  7
# key 4, choosen_index  113
# key 1, choosen_index  57
# key 2, choosen_index  53
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.554022988505747
# precision_score_fcg 0.376025641025641
# f1_score_fcg 0.37534280144806464
# Not good accuracy result !!!!!
# Experiment number: 19
# key 3, choosen_index  0
# key 0, choosen_index  71
# key 4, choosen_index  12
# key 1, choosen_index  118
# key 2, choosen_index  97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.46469622331691296
# precision_score_fcg 0.3185964912280702
# f1_score_fcg 0.33969165337586393
# Not good accuracy result !!!!!
# Experiment number: 20
# key 3, choosen_index  106
# key 0, choosen_index  4
# key 4, choosen_index  52
# key 1, choosen_index  118
# key 2, choosen_index  31
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5080459770114942
# precision_score_fcg 0.38499999999999995
# f1_score_fcg 0.3973377889167363
# Not good accuracy result !!!!!
# Experiment number: 21
# key 3, choosen_index  8
# key 0, choosen_index  10
# key 4, choosen_index  105
# key 1, choosen_index  123
# key 2, choosen_index  108
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.31666666666666665
# recall_score_fcg 0.5333333333333333
# precision_score_fcg 0.26078754578754576
# f1_score_fcg 0.3208465608465609
# Not good accuracy result !!!!!
# Experiment number: 22
# key 3, choosen_index  59
# key 0, choosen_index  71
# key 4, choosen_index  80
# key 1, choosen_index  107
# key 2, choosen_index  97
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.31666666666666665
# recall_score_fcg 0.36091954022988504
# precision_score_fcg 0.3226923076923077
# f1_score_fcg 0.3000898040898041
# Not good accuracy result !!!!!
# Experiment number: 23
# key 3, choosen_index  42
# key 0, choosen_index  71
# key 4, choosen_index  90
# key 1, choosen_index  124
# key 2, choosen_index  58
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.3
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall_score_fcg 0.4509031198686372
# precision_score_fcg 0.3306410256410256
# f1_score_fcg 0.30451127819548873
# Not good accuracy result !!!!!
# Experiment number: 24
# key 3, choosen_index  8
# key 0, choosen_index  50
# key 4, choosen_index  14
# key 1, choosen_index  123
# key 2, choosen_index  89
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.35
# recall_score_fcg 0.5175697865353037
# precision_score_fcg 0.3606410256410256
# f1_score_fcg 0.3544962406015038
# Not good accuracy result !!!!!
# Experiment number: 25
# key 3, choosen_index  0
# key 0, choosen_index  110
# key 4, choosen_index  3
# key 1, choosen_index  131
# key 2, choosen_index  49
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.4
# recall_score_fcg 0.49802955665024634
# precision_score_fcg 0.2985964912280702
# f1_score_fcg 0.333676615781879
# Not good accuracy result !!!!!
# Experiment number: 26
# key 3, choosen_index  36
# key 0, choosen_index  44
# key 4, choosen_index  26
# key 1, choosen_index  51
# key 2, choosen_index  53
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.4
# recall_score_fcg 0.49802955665024634
# precision_score_fcg 0.2985964912280702
# f1_score_fcg 0.333676615781879
# Not good accuracy result !!!!!
# Experiment number: 27
# key 3, choosen_index  36
# key 0, choosen_index  68
# key 4, choosen_index  34
# key 1, choosen_index  101
# key 2, choosen_index  43
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.3
# recall_score_fcg 0.4344827586206897
# precision_score_fcg 0.2707875457875458
# f1_score_fcg 0.258985754985755
# Not good accuracy result !!!!!
# Experiment number: 28
# key 3, choosen_index  42
# key 0, choosen_index  46
# key 4, choosen_index  109
# key 1, choosen_index  15
# key 2, choosen_index  89
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.3
# recall_score_fcg 0.49688013136289
# precision_score_fcg 0.3388095238095238
# f1_score_fcg 0.3104761904761905
# Not good accuracy result !!!!!
# Experiment number: 29
# key 3, choosen_index  74
# key 0, choosen_index  11
# key 4, choosen_index  128
# key 1, choosen_index  124
# key 2, choosen_index  53
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.46469622331691296
# precision_score_fcg 0.3185964912280702
# f1_score_fcg 0.33969165337586393
# Not good accuracy result !!!!!
# Experiment number: 30
# key 3, choosen_index  74
# key 0, choosen_index  66
# key 4, choosen_index  79
# key 1, choosen_index  134
# key 2, choosen_index  53
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5080459770114942
# precision_score_fcg 0.38499999999999995
# f1_score_fcg 0.3973377889167363
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.4166666666666667
# max_recall_score_fcg 0.59688013136289
# max_precision_score_fcg 0.41500000000000004
# max_f1_score_fcg 0.44732275132275134
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# all_accuracy_score_baseline mean 0.5166666666666669
# all_recall_score_baseline mean 0.2581280788177339
# all_precision_score_baseline mean 0.22
# all_f1_score_baseline mean 0.22658227848101267
# all_accuracy_score_fcg mean 0.3444444444444445
# all_recall_score_fcg mean 0.4710727969348659
# all_precision_score_fcg mean 0.3265144592249855
# all_f1_score_fcg mean 0.3325309857029156
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 0.05061407387256622
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.516667  2.258405e-16  4.123265e-17
# 1       all_accuracy_score_fcg  30.0  0.344444  5.015939e-02  9.157809e-03
# 2                     combined  60.0  0.430556  9.368812e-02  1.209508e-02
#
#    95% Conf.  Interval
# 0   0.516667  0.516667
# 1   0.325715  0.363174
# 2   0.406353  0.454758
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  1.722000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   1.880600e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   4.855700e+00
# 7                                       Hedge's g =   4.792600e+00
# 8                                  Glass's delta1 =   7.625834e+14
# 9                                Point-Biserial r =   9.269000e-01
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 0.003168629016727209
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.258128  5.646013e-17  1.030816e-17
# 1       all_recall_score_fcg  30.0  0.471073  7.945948e-02  1.450725e-02
# 2                   combined  60.0  0.364600  1.209624e-01  1.561618e-02
#
#    95% Conf.  Interval
# 0   0.258128  0.258128
# 1   0.441402  0.500743
# 2   0.333353  0.395848
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -2.129000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.467850e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.790000e+00
# 7                                       Hedge's g =  -3.740800e+00
# 8                                  Glass's delta1 =  -3.771595e+15
# 9                                Point-Biserial r =  -8.876000e-01
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 0.13291527330875397
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.220000  2.823006e-17  5.154081e-18
# 1       all_precision_score_fcg  30.0  0.326514  4.782978e-02  8.732482e-03
# 2                      combined  60.0  0.273257  6.331558e-02  8.174006e-03
#
#    95% Conf.  Interval
# 0   0.220000  0.220000
# 1   0.308655  0.344374
# 2   0.256901  0.289613
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all... -1.065000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.219750e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.149400e+00
# 7                                       Hedge's g =  -3.108500e+00
# 8                                  Glass's delta1 =  -3.773086e+15
# 9                                Point-Biserial r =  -8.482000e-01
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 0.11875131726264954
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.226582  5.646013e-17  1.030816e-17
# 1       all_f1_score_fcg  30.0  0.332531  5.669606e-02  1.035124e-02
# 2               combined  60.0  0.279557  6.658699e-02  8.596343e-03
#
#    95% Conf.  Interval
# 0   0.226582  0.226582
# 1   0.311360  0.353702
# 2   0.262355  0.296758
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco... -1.059000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.023540e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.642800e+00
# 7                                       Hedge's g =  -2.608400e+00
# 8                                  Glass's delta1 =  -1.876523e+15
# 9                                Point-Biserial r =  -8.023000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment_M
scope_num = 2
topology_ratio =2


dic={0:36,3:40,4:137,1:83,2:108}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.21666666666666667
# recall_score_fcg 0.22758620689655173
# precision_score_fcg 0.2476923076923077
# f1_score_fcg 0.2040898040898041
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# accuracy_score_baseline 0.5166666666666667
# recall_score_baseline 0.258128078817734
# precision_score_baseline 0.22000000000000003
# f1_score_baseline 0.22658227848101262
# accuracy_score_fcg 0.21666666666666667
# recall_score_fcg 0.22758620689655173
# precision_score_fcg 0.2476923076923077
# f1_score_fcg 0.2040898040898041
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.21666666666666667
# max_recall_score_fcg 0.22758620689655173
# max_precision_score_fcg 0.2476923076923077
# max_f1_score_fcg 0.2040898040898041
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# all_accuracy_score_baseline mean 0.5166666666666667
# all_recall_score_baseline mean 0.258128078817734
# all_precision_score_baseline mean 0.22000000000000003
# all_f1_score_baseline mean 0.22658227848101262
# all_accuracy_score_fcg mean 0.21666666666666667
# all_recall_score_fcg mean 0.22758620689655173
# all_precision_score_fcg mean 0.2476923076923077
# all_f1_score_fcg mean 0.2040898040898041
# len plot_unit 2  len (all_test_score_baseline_accuracy) 2
# Normal test + all_test_score_baseline_accuracy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       7 #print(experiment.train_new_embedding_fcg_fuzzy)
#       8 experiment_M = experiment_M.Experiment()
# ----> 9 experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy)
#
# File C:\JupyterDoc\FCG\VersionStore\Version2FCGClassification TFCG_TineTuneComparision\experiment_M.py:268, in Experiment.Ttest(self, dataread, scope_num, topology_ratio, nfolder, dic, class_num, class_index_group_dic, all_features_mapping_fuzzy, train_new_embedding_fcg_fuzzy)
#     265 plt.show()
#     267 print(f"Normal test + all_test_score_baseline_accuracy")
# --> 268 shapiro_test = stats.shapiro(all_test_score_baseline_accuracy)
#     269 print(shapiro_test.pvalue)
#     270 print(f"Normal test + all_test_score_fcg_accuracy")
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1869, in shapiro(x)
#    1867 N = len(x)
#    1868 if N < 3:
# -> 1869     raise ValueError("Data must be at least length 3.")
#    1871 x = x - np.median(x)
#    1873 a = zeros(N, 'f')
#
# ValueError: Data must be at least length 3.
