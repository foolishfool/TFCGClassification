# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# continuous_feature_num 2
# discrete_feature_num 9
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
import experiment
scope_num = 30
topology_ratio =2


experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.09
# recall_score_baseline 0.09502256975210192
# precision_score_baseline 0.09126890085223419
# f1_score_baseline 0.08515195456056714
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 2
# accuracy_score_baseline 0.12
# recall_score_baseline 0.12788457099053993
# precision_score_baseline 0.12637577537351896
# f1_score_baseline 0.11887138759917722
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 3
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.13015035835942268
# precision_score_baseline 0.12498121662377527
# f1_score_baseline 0.11534247899344997
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 4
# accuracy_score_baseline 0.15666666666666668
# recall_score_baseline 0.16094773099007822
# precision_score_baseline 0.1572355960894219
# f1_score_baseline 0.153715807694291
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# accuracy_score_baseline 0.12666666666666668
# recall_score_baseline 0.136136556293594
# precision_score_baseline 0.14303603538897655
# f1_score_baseline 0.12852939684703985
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 6
# accuracy_score_baseline 0.11333333333333333
# recall_score_baseline 0.11960051207782604
# precision_score_baseline 0.10783234313963809
# f1_score_baseline 0.1055898876733492
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 7
# accuracy_score_baseline 0.12
# recall_score_baseline 0.12473996535904178
# precision_score_baseline 0.1147546190193249
# f1_score_baseline 0.11100448605880418
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 8
# accuracy_score_baseline 0.1
# recall_score_baseline 0.10496204567690753
# precision_score_baseline 0.10195235471932651
# f1_score_baseline 0.09767439117608323
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 9
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.12342025993619056
# precision_score_baseline 0.1497008483528091
# f1_score_baseline 0.12748730090684113
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 10
# accuracy_score_baseline 0.11333333333333333
# recall_score_baseline 0.11841191796298671
# precision_score_baseline 0.11321586811476671
# f1_score_baseline 0.10668116491569309
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 11
# accuracy_score_baseline 0.10333333333333333
# recall_score_baseline 0.10430882903105126
# precision_score_baseline 0.08534273891412918
# f1_score_baseline 0.0880436366851831
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 12
# accuracy_score_baseline 0.14
# recall_score_baseline 0.153570818591236
# precision_score_baseline 0.14015663078179197
# f1_score_baseline 0.1378391405333969
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.11214599615839786
# precision_score_baseline 0.10818576385590016
# f1_score_baseline 0.101725669517385
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 14
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11792185822736337
# precision_score_baseline 0.11856738768124966
# f1_score_baseline 0.10724188062522504
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 15
# accuracy_score_baseline 0.09666666666666666
# recall_score_baseline 0.09461424505863908
# precision_score_baseline 0.0984849096639053
# f1_score_baseline 0.09054656277066052
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 16
# accuracy_score_baseline 0.11666666666666667
# recall_score_baseline 0.1196071074053026
# precision_score_baseline 0.11654904888735734
# f1_score_baseline 0.10988724104544319
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 17
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.11234597351480795
# precision_score_baseline 0.1124034346731048
# f1_score_baseline 0.10324897214229217
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 18
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.13230312298219132
# precision_score_baseline 0.11801774647789139
# f1_score_baseline 0.11740785654905826
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 19
# accuracy_score_baseline 0.10333333333333333
# recall_score_baseline 0.1103028308561178
# precision_score_baseline 0.11535718090003394
# f1_score_baseline 0.10333478708248119
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 20
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.11232323147452207
# precision_score_baseline 0.11988691773005497
# f1_score_baseline 0.10414032258363756
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 21
# accuracy_score_baseline 0.11666666666666667
# recall_score_baseline 0.11573635884963772
# precision_score_baseline 0.12784533869952247
# f1_score_baseline 0.1172725825746656
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 22
# accuracy_score_baseline 0.1
# recall_score_baseline 0.10356609382118556
# precision_score_baseline 0.0937023301579074
# f1_score_baseline 0.09253463242063474
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 23
# accuracy_score_baseline 0.11333333333333333
# recall_score_baseline 0.11792643786795834
# precision_score_baseline 0.11765711454872291
# f1_score_baseline 0.10837301583257572
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 24
# accuracy_score_baseline 0.11333333333333333
# recall_score_baseline 0.11896907503481409
# precision_score_baseline 0.1061924894914231
# f1_score_baseline 0.1022755520277574
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 25
# accuracy_score_baseline 0.12
# recall_score_baseline 0.12252062365946213
# precision_score_baseline 0.12897888775469665
# f1_score_baseline 0.11365019609766616
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 26
# accuracy_score_baseline 0.12666666666666668
# recall_score_baseline 0.12547184726202673
# precision_score_baseline 0.1315534878527505
# f1_score_baseline 0.12201695913803319
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 27
# accuracy_score_baseline 0.09666666666666666
# recall_score_baseline 0.10582503888790437
# precision_score_baseline 0.08989148952545922
# f1_score_baseline 0.09101137006242445
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 28
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11491365815851598
# precision_score_baseline 0.1052039615397739
# f1_score_baseline 0.10383579804042321
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 29
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11722524787432026
# precision_score_baseline 0.11849060921641567
# f1_score_baseline 0.1083555815727743
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# Experiment number: 30
# accuracy_score_baseline 0.11666666666666667
# recall_score_baseline 0.12230482125143347
# precision_score_baseline 0.11331654113039666
# f1_score_baseline 0.10657065473004751
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.14237553154723956
# precision_score_fcg 0.16421791523972873
# f1_score_fcg 0.1373637220235716
# all_accuracy_score_baseline mean 0.11411111111111111
# all_recall_score_baseline mean 0.11917265677885257
# all_precision_score_baseline mean 0.1165379189052093
# all_f1_score_baseline mean 0.10931202228190205
# all_accuracy_score_fcg mean 0.13666666666666666
# all_recall_score_fcg mean 0.14237553154723953
# all_precision_score_fcg mean 0.16421791523972865
# all_f1_score_fcg mean 0.13736372202357164
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + [0.09, 0.12, 0.12333333333333334, 0.15666666666666668, 0.12666666666666668, 0.11333333333333333, 0.12, 0.1, 0.12333333333333334, 0.11333333333333333, 0.10333333333333333, 0.14, 0.10666666666666667, 0.11, 0.09666666666666666, 0.11666666666666667, 0.10666666666666667, 0.12333333333333334, 0.10333333333333333, 0.10666666666666667, 0.11666666666666667, 0.1, 0.11333333333333333, 0.11333333333333333, 0.12, 0.12666666666666668, 0.09666666666666666, 0.11, 0.11, 0.11666666666666667]
# Normal test + [0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666, 0.13666666666666666]
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  30.0  0.114111  0.013410  0.002448   0.109104
# 1       all_accuracy_score_fcg  30.0  0.136667  0.000000  0.000000        NaN
# 2                     combined  60.0  0.125389  0.014756  0.001905   0.121577
#
#    Interval
# 0  0.119119
# 1       NaN
# 2  0.129201
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0226
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -9.2125
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.3787
# 7                                       Hedge's g =   -2.3478
# 8                                  Glass's delta1 =   -1.6820
# 9                                Point-Biserial r =   -0.7707
# Normal test + [0.09502256975210192, 0.12788457099053993, 0.13015035835942268, 0.16094773099007822, 0.136136556293594, 0.11960051207782604, 0.12473996535904178, 0.10496204567690753, 0.12342025993619056, 0.11841191796298671, 0.10430882903105126, 0.153570818591236, 0.11214599615839786, 0.11792185822736337, 0.09461424505863908, 0.1196071074053026, 0.11234597351480795, 0.13230312298219132, 0.1103028308561178, 0.11232323147452207, 0.11573635884963772, 0.10356609382118556, 0.11792643786795834, 0.11896907503481409, 0.12252062365946213, 0.12547184726202673, 0.10582503888790437, 0.11491365815851598, 0.11722524787432026, 0.12230482125143347]
# Normal test + [0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956, 0.14237553154723956]
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.119173  1.436600e-02  2.622860e-03
# 1       all_recall_score_fcg  30.0  0.142376  2.823006e-17  5.154081e-18
# 2                   combined  60.0  0.130774  1.543750e-02  1.992973e-03
#
#    95% Conf.  Interval
# 0   0.113808  0.124537
# 1   0.142376  0.142376
# 2   0.126786  0.134762
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0232
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -8.8464
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.2841
# 7                                       Hedge's g =   -2.2545
# 8                                  Glass's delta1 =   -1.6151
# 9                                Point-Biserial r =   -0.7579
# Normal test + [0.09126890085223419, 0.12637577537351896, 0.12498121662377527, 0.1572355960894219, 0.14303603538897655, 0.10783234313963809, 0.1147546190193249, 0.10195235471932651, 0.1497008483528091, 0.11321586811476671, 0.08534273891412918, 0.14015663078179197, 0.10818576385590016, 0.11856738768124966, 0.0984849096639053, 0.11654904888735734, 0.1124034346731048, 0.11801774647789139, 0.11535718090003394, 0.11988691773005497, 0.12784533869952247, 0.0937023301579074, 0.11765711454872291, 0.1061924894914231, 0.12897888775469665, 0.1315534878527505, 0.08989148952545922, 0.1052039615397739, 0.11849060921641567, 0.11331654113039666]
# Normal test + [0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873, 0.16421791523972873]
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.116538  1.714116e-02  3.129533e-03
# 1       all_precision_score_fcg  30.0  0.164218  8.469019e-17  1.546224e-17
# 2                      combined  60.0  0.140378  2.687747e-02  3.469866e-03
#
#    95% Conf.  Interval
# 0   0.110137  0.122939
# 1   0.164218  0.164218
# 2   0.133435  0.147321
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0477
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -15.2355
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.9338
# 7                                       Hedge's g =   -3.8827
# 8                                  Glass's delta1 =   -2.7816
# 9                                Point-Biserial r =   -0.8945
# Normal test + [0.08515195456056714, 0.11887138759917722, 0.11534247899344997, 0.153715807694291, 0.12852939684703985, 0.1055898876733492, 0.11100448605880418, 0.09767439117608323, 0.12748730090684113, 0.10668116491569309, 0.0880436366851831, 0.1378391405333969, 0.101725669517385, 0.10724188062522504, 0.09054656277066052, 0.10988724104544319, 0.10324897214229217, 0.11740785654905826, 0.10333478708248119, 0.10414032258363756, 0.1172725825746656, 0.09253463242063474, 0.10837301583257572, 0.1022755520277574, 0.11365019609766616, 0.12201695913803319, 0.09101137006242445, 0.10383579804042321, 0.1083555815727743, 0.10657065473004751]
# Normal test + [0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716, 0.1373637220235716]
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.109312  1.478107e-02  2.698641e-03
# 1       all_f1_score_fcg  30.0  0.137364  2.823006e-17  5.154081e-18
# 2               combined  60.0  0.123338  1.753417e-02  2.263652e-03
#
#    95% Conf.  Interval
# 0   0.103793  0.114831
# 1   0.137364  0.137364
# 2   0.118808  0.127867
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0281
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -10.3947
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.6839
# 7                                       Hedge's g =   -2.6491
# 8                                  Glass's delta1 =   -1.8978
# 9                                Point-Biserial r =   -0.8067
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment
scope_num = 30
topology_ratio =2


experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.08
# recall_score_baseline 0.07978598967091705
# precision_score_baseline 0.0905144186087048
# f1_score_baseline 0.07852835194639246
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 2
# accuracy_score_baseline 0.12
# recall_score_baseline 0.12003618138309707
# precision_score_baseline 0.10739973329854619
# f1_score_baseline 0.10888442351481517
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good recall_score result !!!!!
# Experiment number: 3
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10641117038023282
# precision_score_baseline 0.10945078266117415
# f1_score_baseline 0.10496323521784978
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 4
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10381861501461577
# precision_score_baseline 0.09432948468036188
# f1_score_baseline 0.09417115352321696
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 5
# accuracy_score_baseline 0.11333333333333333
# recall_score_baseline 0.11235538904846581
# precision_score_baseline 0.10390958185075833
# f1_score_baseline 0.10355380735457592
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 6
# accuracy_score_baseline 0.12
# recall_score_baseline 0.12087290216888406
# precision_score_baseline 0.12318780566321613
# f1_score_baseline 0.1179088091372851
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# accuracy_score_baseline 0.11666666666666667
# recall_score_baseline 0.1150019936663966
# precision_score_baseline 0.10837784746805845
# f1_score_baseline 0.10913103584576027
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 8
# accuracy_score_baseline 0.11666666666666667
# recall_score_baseline 0.115529992223069
# precision_score_baseline 0.1067066610577401
# f1_score_baseline 0.10841739782238896
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 9
# accuracy_score_baseline 0.12
# recall_score_baseline 0.12024541047366928
# precision_score_baseline 0.11274988582141458
# f1_score_baseline 0.11160603546904414
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good recall_score result !!!!!
# Experiment number: 10
# accuracy_score_baseline 0.12
# recall_score_baseline 0.11846372607549743
# precision_score_baseline 0.10432104780224885
# f1_score_baseline 0.10699102451095062
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 11
# accuracy_score_baseline 0.13333333333333333
# recall_score_baseline 0.13132148776366848
# precision_score_baseline 0.12263608450221025
# f1_score_baseline 0.12325377782191355
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# accuracy_score_baseline 0.12
# recall_score_baseline 0.12093480955016513
# precision_score_baseline 0.12275332386418342
# f1_score_baseline 0.11583285608447547
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10639370202660148
# precision_score_baseline 0.10259457191811061
# f1_score_baseline 0.10044805222517576
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 14
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10564583906406205
# precision_score_baseline 0.11577903318827154
# f1_score_baseline 0.10322125378006825
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 15
# accuracy_score_baseline 0.12666666666666668
# recall_score_baseline 0.12374308040220133
# precision_score_baseline 0.11856073388232678
# f1_score_baseline 0.11413312100968742
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Experiment number: 16
# accuracy_score_baseline 0.13
# recall_score_baseline 0.1308947695101251
# precision_score_baseline 0.1300953804823774
# f1_score_baseline 0.12313714893609967
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# accuracy_score_baseline 0.12666666666666668
# recall_score_baseline 0.12537372443993836
# precision_score_baseline 0.12405036084042169
# f1_score_baseline 0.11848179303080918
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10486421555087845
# precision_score_baseline 0.09317508075072274
# f1_score_baseline 0.09630057911220292
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 19
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10725148168083463
# precision_score_baseline 0.10354224959959728
# f1_score_baseline 0.09920284474528565
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 20
# accuracy_score_baseline 0.12666666666666668
# recall_score_baseline 0.12698720090721602
# precision_score_baseline 0.1268104982119138
# f1_score_baseline 0.11981614613458352
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# accuracy_score_baseline 0.13333333333333333
# recall_score_baseline 0.12992071085826978
# precision_score_baseline 0.13772069525821795
# f1_score_baseline 0.12535463716246176
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# accuracy_score_baseline 0.11333333333333333
# recall_score_baseline 0.1131196453682777
# precision_score_baseline 0.10121569549218129
# f1_score_baseline 0.10441412718329984
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 23
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10704606970405876
# precision_score_baseline 0.105429700069175
# f1_score_baseline 0.10213760321731546
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 24
# accuracy_score_baseline 0.10666666666666667
# recall_score_baseline 0.10794527111259804
# precision_score_baseline 0.1111021263612002
# f1_score_baseline 0.10637007507065259
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 25
# accuracy_score_baseline 0.12666666666666668
# recall_score_baseline 0.12606751387170176
# precision_score_baseline 0.1240919680574853
# f1_score_baseline 0.12085091775792682
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11042570853927201
# precision_score_baseline 0.10438494170709618
# f1_score_baseline 0.1018344574240578
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 27
# accuracy_score_baseline 0.09333333333333334
# recall_score_baseline 0.08928739017401534
# precision_score_baseline 0.08436980550732673
# f1_score_baseline 0.08515618435063381
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 28
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11328937609828008
# precision_score_baseline 0.11337211110471143
# f1_score_baseline 0.10826131305838654
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 29
# accuracy_score_baseline 0.11666666666666667
# recall_score_baseline 0.11639123965100197
# precision_score_baseline 0.11522255611789792
# f1_score_baseline 0.11061998217891701
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Experiment number: 30
# accuracy_score_baseline 0.12333333333333334
# recall_score_baseline 0.1242743498072681
# precision_score_baseline 0.11709253422267883
# f1_score_baseline 0.11534187465018338
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11884717741159924
# precision_score_fcg 0.12121835685625047
# f1_score_fcg 0.11548155597687056
# Not good recall_score result !!!!!
# all_accuracy_score_baseline mean 0.115
# all_recall_score_baseline mean 0.11445663187284263
# all_precision_score_baseline mean 0.11116489000167767
# all_f1_score_baseline mean 0.10794413397588053
# all_accuracy_score_fcg mean 0.12333333333333336
# all_recall_score_fcg mean 0.11884717741159927
# all_precision_score_fcg mean 0.1212183568562505
# all_f1_score_fcg mean 0.11548155597687058
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.115000  1.167077e-02  2.130782e-03
# 1       all_accuracy_score_fcg  30.0  0.123333  2.823006e-17  5.154081e-18
# 2                     combined  60.0  0.119167  9.198072e-03  1.187466e-03
#
#    95% Conf.  Interval
# 0   0.110642  0.119358
# 1   0.123333  0.123333
# 2   0.116791  0.121543
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0083
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -3.9109
# 3                           Two side test p value =    0.0002
# 4                          Difference < 0 p value =    0.0001
# 5                          Difference > 0 p value =    0.9999
# 6                                       Cohen's d =   -1.0098
# 7                                       Hedge's g =   -0.9967
# 8                                  Glass's delta1 =   -0.7140
# 9                                Point-Biserial r =   -0.4568
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.114457  1.171144e-02  2.138206e-03
# 1       all_recall_score_fcg  30.0  0.118847  2.823006e-17  5.154081e-18
# 2                   combined  60.0  0.116652  8.503964e-03  1.097857e-03
#
#    95% Conf.  Interval
# 0   0.110084  0.118830
# 1   0.118847  0.118847
# 2   0.114455  0.118849
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0044
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -2.0534
# 3                           Two side test p value =    0.0446
# 4                          Difference < 0 p value =    0.0223
# 5                          Difference > 0 p value =    0.9777
# 6                                       Cohen's d =   -0.5302
# 7                                       Hedge's g =   -0.5233
# 8                                  Glass's delta1 =   -0.3749
# 9                                Point-Biserial r =   -0.2603
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.111165  1.230648e-02  2.246845e-03
# 1       all_precision_score_fcg  30.0  0.121218  2.823006e-17  5.154081e-18
# 2                      combined  60.0  0.116192  1.000688e-02  1.291882e-03
#
#    95% Conf.  Interval
# 0   0.106570  0.115760
# 1   0.121218  0.121218
# 2   0.113607  0.118777
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0101
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -4.4745
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.1553
# 7                                       Hedge's g =   -1.1403
# 8                                  Glass's delta1 =   -0.8169
# 9                                Point-Biserial r =   -0.5066
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.107944  1.089837e-02  1.989761e-03
# 1       all_f1_score_fcg  30.0  0.115482  2.823006e-17  5.154081e-18
# 2               combined  60.0  0.111713  8.533732e-03  1.101700e-03
#
#    95% Conf.  Interval
# 0   0.103875  0.112014
# 1   0.115482  0.115482
# 2   0.109508  0.113917
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0075
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -3.7881
# 3                           Two side test p value =    0.0004
# 4                          Difference < 0 p value =    0.0002
# 5                          Difference > 0 p value =    0.9998
# 6                                       Cohen's d =   -0.9781
# 7                                       Hedge's g =   -0.9654
# 8                                  Glass's delta1 =   -0.6916
# 9                                Point-Biserial r =   -0.4454
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
