# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# continuous_feature_num 1
# discrete_feature_num 10
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
import experiment
scope_num = 30
topology_ratio =2


experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio,nfolder =5)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 2
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 3
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 4
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 5
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 6
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 7
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 8
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 9
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 10
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 11
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 12
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.55
# recall_score_baseline 0.5532212885154062
# precision_score_baseline 0.5592691622103387
# f1_score_baseline 0.5396419437340153
# accuracy_score_fcg 0.48
# recall_score_fcg 0.48099239695878354
# precision_score_fcg 0.4808080808080808
# f1_score_fcg 0.47916666666666663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# accuracy_score_baseline 0.48
# recall_score_baseline 0.4799479947994799
# precision_score_baseline 0.4799479947994799
# f1_score_baseline 0.4799479947994799
# accuracy_score_fcg 0.555
# recall_score_fcg 0.555005500550055
# precision_score_fcg 0.555
# f1_score_fcg 0.5549888747218681
# accuracy_score_baseline 0.51
# recall_score_baseline 0.5155640076068462
# precision_score_baseline 0.5180164523230216
# f1_score_baseline 0.4954175677067243
# accuracy_score_fcg 0.53
# recall_score_fcg 0.5286758082274047
# precision_score_fcg 0.5288839600766206
# f1_score_fcg 0.5283018867924528
# accuracy_score_baseline 0.46733668341708545
# recall_score_baseline 0.46674752375176876
# precision_score_baseline 0.4667004048582996
# f1_score_baseline 0.46667677993527507
# accuracy_score_fcg 0.49246231155778897
# recall_score_fcg 0.49226804123711343
# precision_score_fcg 0.4922711658920994
# f1_score_fcg 0.4922571681192371
# Experiment number: 13
# accuracy_score_baseline 0.495
# recall_score_baseline 0.4934765154556403
# precision_score_baseline 0.49348370927318297
# f1_score_baseline 0.49346773991323756
# accuracy_score_fcg 0.475
# recall_score_fcg 0.4728020875150542
# precision_score_fcg 0.4727665561250125
# f1_score_fcg 0.4727724636589591
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
