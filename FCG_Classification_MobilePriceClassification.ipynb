# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Mobile Price Classification/train.csv")
csv_original_encode = csv

#dataread.hash_encoding(csv_original_encode,["blue","dual_sim","fc","four_g","mobile_wt","n_cores","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"])
dataread.label_encoding(csv,"blue")
dataread.label_encoding(csv,"dual_sim")
dataread.label_encoding(csv,"fc")
dataread.label_encoding(csv,"four_g")
dataread.label_encoding(csv,"mobile_wt")
dataread.label_encoding(csv,"n_cores")
dataread.label_encoding(csv,"sc_h")
dataread.label_encoding(csv,"sc_w")
dataread.label_encoding(csv,"talk_time")
dataread.label_encoding(csv,"three_g")
dataread.label_encoding(csv,"touch_screen")
dataread.label_encoding(csv,"wifi")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"price_range")
# Out:
# continuous_feature_num 8
# discrete_feature_num 12
# self.data_discrete_indexes ['blue', 'dual_sim', 'fc', 'four_g', 'm_dep', 'n_cores', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi']

# %%
import experiment 
scope_num = 30 
topology_ratio = 2

experiment = experiment.Experiment() 
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# self.random_dic {1: 0, 2: 133, 0: 739, 3: 58}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25833333333333336
# recall_score_fcg 0.2586945168506091
# precision_score_fcg 0.25068553989577347
# f1_score_fcg 0.22316664089560243
# Not good accuracy result !!!!!
# Experiment number: 2
# self.random_dic {1: 35, 2: 175, 0: 1186, 3: 112}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25666666666666665
# recall_score_fcg 0.25975519013550735
# precision_score_fcg 0.258654665304415
# f1_score_fcg 0.22406066252969226
# Not good accuracy result !!!!!
# Experiment number: 3
# self.random_dic {1: 896, 2: 459, 0: 281, 3: 202}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.24833333333333332
# recall_score_fcg 0.24630208622187716
# precision_score_fcg 0.23639027423111125
# f1_score_fcg 0.23312340554664243
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# self.random_dic {1: 79, 2: 169, 0: 964, 3: 629}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.26166666666666666
# recall_score_fcg 0.25725833287116634
# precision_score_fcg 0.2741350406638226
# f1_score_fcg 0.2296675915030137
# Not good accuracy result !!!!!
# Experiment number: 5
# self.random_dic {1: 944, 2: 1143, 0: 1227, 3: 618}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.2783333333333333
# recall_score_fcg 0.2775630626883331
# precision_score_fcg 0.2843764182698869
# f1_score_fcg 0.27010659641568197
# Experiment number: 6
# self.random_dic {1: 436, 2: 130, 0: 1067, 3: 579}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.23333333333333334
# recall_score_fcg 0.23578258739578134
# precision_score_fcg 0.24118237466402093
# f1_score_fcg 0.20518257821180558
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# self.random_dic {1: 379, 2: 776, 0: 653, 3: 1269}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.24
# recall_score_fcg 0.24091726286210785
# precision_score_fcg 0.23788044544227172
# f1_score_fcg 0.23022787453226218
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# self.random_dic {1: 617, 2: 1097, 0: 430, 3: 1158}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.24211774166712885
# precision_score_fcg 0.25481217004784856
# f1_score_fcg 0.2127002829275535
# Not good accuracy result !!!!!
# Experiment number: 9
# self.random_dic {1: 1351, 2: 978, 0: 60, 3: 18}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.2783333333333333
# recall_score_fcg 0.2775630626883331
# precision_score_fcg 0.2843764182698869
# f1_score_fcg 0.27010659641568197
# Experiment number: 10
# self.random_dic {1: 35, 2: 425, 0: 979, 3: 266}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.27666666666666667
# recall_score_fcg 0.27868959477196675
# precision_score_fcg 0.2848022959548007
# f1_score_fcg 0.2699578524854276
# Experiment number: 11
# self.random_dic {1: 1215, 2: 279, 0: 1322, 3: 401}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.26
# recall_score_fcg 0.25828838759174017
# precision_score_fcg 0.2535442703324758
# f1_score_fcg 0.2472214876847154
# Experiment number: 12
# self.random_dic {1: 1318, 2: 1082, 0: 1004, 3: 1334}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25666666666666665
# recall_score_fcg 0.25975519013550735
# precision_score_fcg 0.25867308558145596
# f1_score_fcg 0.22405171200615537
# Not good accuracy result !!!!!
# Experiment number: 13
# self.random_dic {1: 944, 2: 453, 0: 1155, 3: 271}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25833333333333336
# recall_score_fcg 0.2553206976873163
# precision_score_fcg 0.2580060084057581
# f1_score_fcg 0.2245586865728752
# Not good accuracy result !!!!!
# Experiment number: 14
# self.random_dic {1: 1118, 2: 902, 0: 196, 3: 105}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.245
# recall_score_fcg 0.24704213114451037
# precision_score_fcg 0.24607614113796739
# f1_score_fcg 0.23663251226423399
# Not good accuracy result !!!!!
# Experiment number: 15
# self.random_dic {1: 79, 2: 810, 0: 830, 3: 1354}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25333333333333335
# recall_score_fcg 0.2551138779509363
# precision_score_fcg 0.26625510929251195
# f1_score_fcg 0.22173529309365805
# Not good accuracy result !!!!!
# Experiment number: 16
# self.random_dic {1: 84, 2: 149, 0: 487, 3: 780}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.21833333333333332
# recall_score_fcg 0.21597988649178268
# precision_score_fcg 0.2155772925747561
# f1_score_fcg 0.20915639406300585
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# self.random_dic {1: 176, 2: 1228, 0: 976, 3: 445}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.24666666666666667
# recall_score_fcg 0.25089891483186366
# precision_score_fcg 0.23990638849162207
# f1_score_fcg 0.21246989734244306
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# self.random_dic {1: 1195, 2: 777, 0: 897, 3: 619}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.255
# recall_score_fcg 0.25632822176621745
# precision_score_fcg 0.2521597850228161
# f1_score_fcg 0.2444310042043443
# Experiment number: 19
# self.random_dic {1: 907, 2: 462, 0: 886, 3: 473}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25333333333333335
# recall_score_fcg 0.25242695450427965
# precision_score_fcg 0.24458596992680698
# f1_score_fcg 0.23952804327861427
# Experiment number: 20
# self.random_dic {1: 428, 2: 239, 0: 1016, 3: 1243}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25
# recall_score_fcg 0.2501328730149927
# precision_score_fcg 0.23990967782680797
# f1_score_fcg 0.213624656162778
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# self.random_dic {1: 832, 2: 470, 0: 463, 3: 693}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.26
# recall_score_fcg 0.25828838759174017
# precision_score_fcg 0.2535442703324758
# f1_score_fcg 0.2472214876847154
# Experiment number: 22
# self.random_dic {1: 1205, 2: 454, 0: 711, 3: 131}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.26
# recall_score_fcg 0.25828838759174017
# precision_score_fcg 0.2535442703324758
# f1_score_fcg 0.2472214876847154
# Experiment number: 23
# self.random_dic {1: 428, 2: 243, 0: 380, 3: 935}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.26166666666666666
# recall_score_fcg 0.25725833287116634
# precision_score_fcg 0.2741350406638226
# f1_score_fcg 0.2296675915030137
# Not good accuracy result !!!!!
# Experiment number: 24
# self.random_dic {1: 41, 2: 846, 0: 1327, 3: 1298}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.245
# recall_score_fcg 0.24704213114451037
# precision_score_fcg 0.24607614113796739
# f1_score_fcg 0.23663251226423399
# Not good accuracy result !!!!!
# Experiment number: 25
# self.random_dic {1: 578, 2: 157, 0: 823, 3: 98}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.23833333333333334
# recall_score_fcg 0.23700097517238833
# precision_score_fcg 0.24055160899644096
# f1_score_fcg 0.23141998710562237
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# self.random_dic {1: 1328, 2: 827, 0: 260, 3: 1175}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.235
# recall_score_fcg 0.23391427726323183
# precision_score_fcg 0.23623874349936494
# f1_score_fcg 0.22770695289590956
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# self.random_dic {1: 1023, 2: 1208, 0: 1098, 3: 135}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.2783333333333333
# recall_score_fcg 0.2775630626883331
# precision_score_fcg 0.2818739157673844
# f1_score_fcg 0.26903530175608587
# Experiment number: 28
# self.random_dic {1: 1144, 2: 242, 0: 6, 3: 1306}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.26
# recall_score_fcg 0.25828838759174017
# precision_score_fcg 0.2535442703324758
# f1_score_fcg 0.2472214876847154
# Experiment number: 29
# self.random_dic {1: 110, 2: 516, 0: 898, 3: 275}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.22666666666666666
# recall_score_fcg 0.22501467380252527
# precision_score_fcg 0.22590011539757893
# f1_score_fcg 0.2183931996271455
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# self.random_dic {1: 524, 2: 1130, 0: 555, 3: 1163}
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.25
# recall_score_fcg 0.2501328730149927
# precision_score_fcg 0.23990967782680797
# f1_score_fcg 0.213624656162778
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.2783333333333333
# max_recall_score_fcg 0.27868959477196675
# max_precision_score_fcg 0.2848022959548007
# max_f1_score_fcg 0.27010659641568197
# all_accuracy_score_baseline mean 0.24000000000000005
# all_recall_score_baseline mean 0.24120380640748346
# all_precision_score_baseline mean 0.24423247643185686
# all_f1_score_baseline mean 0.23829322632822073
# all_accuracy_score_fcg mean 0.253
# all_recall_score_fcg mean 0.25262406873347754
# all_precision_score_fcg mean 0.25291024752078706
# all_f1_score_fcg mean 0.23366181441683737
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 0.2789098918437958
# Accuracy Score T-Test
#                       Variable     N    Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.2400  5.646013e-17  1.030816e-17
# 1       all_accuracy_score_fcg  30.0  0.2530  1.457179e-02  2.660433e-03
# 2                     combined  60.0  0.2465  1.213817e-02  1.567031e-03
#
#    95% Conf.  Interval
# 0   0.240000  0.240000
# 1   0.247559  0.258441
# 2   0.243364  0.249636
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_... -1.300000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -4.886400e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.261700e+00
# 7                                       Hedge's g =  -1.245300e+00
# 8                                  Glass's delta1 =  -2.302510e+14
# 9                                Point-Biserial r =  -5.400000e-01
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 0.0970725566148758
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.241204  2.823006e-17  5.154081e-18
# 1       all_recall_score_fcg  30.0  0.252624  1.465735e-02  2.676054e-03
# 2                   combined  60.0  0.246914  1.177950e-02  1.520727e-03
#
#    95% Conf.  Interval
# 0   0.241204  0.241204
# 1   0.247151  0.258097
# 2   0.243871  0.249957
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -1.140000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -4.267600e+00
# 3                           Two side test p value =   1.000000e-04
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.101900e+00
# 7                                       Hedge's g =  -1.087600e+00
# 8                                  Glass's delta1 =  -4.045426e+14
# 9                                Point-Biserial r =  -4.888000e-01
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 0.139744371175766
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_baseline  30.0  0.244232  0.000000  0.000000
# 1       all_precision_score_fcg  30.0  0.252910  0.017497  0.003195
# 2                      combined  60.0  0.248571  0.013024  0.001681
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.246377  0.259444
# 2   0.245207  0.251936
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0087
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -2.7164
# 3                           Two side test p value =    0.0087
# 4                          Difference < 0 p value =    0.0043
# 5                          Difference > 0 p value =    0.9957
# 6                                       Cohen's d =   -0.7014
# 7                                       Hedge's g =   -0.6923
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.3360
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 0.03295478969812393
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.238293  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  30.0  0.233662  0.018634  0.003402   0.226704
# 2               combined  60.0  0.235978  0.013271  0.001713   0.232549
#
#    Interval
# 0       NaN
# 1  0.240620
# 2  0.239406
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0046
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    1.3614
# 3                           Two side test p value =    0.1787
# 4                          Difference < 0 p value =    0.9107
# 5                          Difference > 0 p value =    0.0893
# 6                                       Cohen's d =    0.3515
# 7                                       Hedge's g =    0.3469
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.1760
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment_M
scope_num =3
topology_ratio =2


dic=  {1: 1023, 2: 1208, 0: 1098, 3: 135}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.2783333333333333
# recall_score_fcg 0.2775630626883331
# precision_score_fcg 0.2818739157673844
# f1_score_fcg 0.26903530175608587
# Experiment number: 2
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.2783333333333333
# recall_score_fcg 0.2775630626883331
# precision_score_fcg 0.2818739157673844
# f1_score_fcg 0.26903530175608587
# Experiment number: 3
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24120380640748343
# precision_score_baseline 0.24423247643185686
# f1_score_baseline 0.23829322632822073
# accuracy_score_fcg 0.2783333333333333
# recall_score_fcg 0.2775630626883331
# precision_score_fcg 0.2818739157673844
# f1_score_fcg 0.26903530175608587
# max_accuracy_score_fcg 0.2783333333333333
# max_recall_score_fcg 0.2775630626883331
# max_precision_score_fcg 0.2818739157673844
# max_f1_score_fcg 0.26903530175608587
# all_accuracy_score_baseline mean 0.24
# all_recall_score_baseline mean 0.24120380640748343
# all_precision_score_baseline mean 0.24423247643185686
# all_f1_score_baseline mean 0.23829322632822073
# all_accuracy_score_fcg mean 0.2783333333333333
# all_recall_score_fcg mean 0.2775630626883331
# all_precision_score_fcg mean 0.2818739157673844
# all_f1_score_fcg mean 0.26903530175608587
# len plot_unit 3  len (all_test_score_baseline_accuracy) 3
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 1.0
# Accuracy Score T-Test
#                       Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  3.0  0.240000  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg  3.0  0.278333  0.000000  0.000000        NaN
# 2                     combined  6.0  0.259167  0.020996  0.008572   0.237133
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.281201
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0383
# 1                              Degrees of freedom =    4.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 1.0
# Recall Score T-Test
#                     Variable    N      Mean        SD       SE  95% Conf.  \
# 0  all_recall_score_baseline  3.0  0.241204  0.000000  0.00000        NaN
# 1       all_recall_score_fcg  3.0  0.277563  0.000000  0.00000        NaN
# 2                   combined  6.0  0.259383  0.019915  0.00813   0.238484
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.280283
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0364
# 1                              Degrees of freedom =    4.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 1.0
# Precision Score T-Test
#                        Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_precision_score_baseline  3.0  0.244232  0.000000  0.000000        NaN
# 1       all_precision_score_fcg  3.0  0.281874  0.000000  0.000000        NaN
# 2                      combined  6.0  0.263053  0.020617  0.008417   0.241417
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.284689
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0376
# 1                              Degrees of freedom =    4.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 1.0
# F1 Score T-Test
#                 Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  3.0  0.238293  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  3.0  0.269035  0.000000  0.000000        NaN
# 2               combined  6.0  0.253664  0.016838  0.006874   0.235994
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.271335
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0307
# 1                              Degrees of freedom =    4.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
