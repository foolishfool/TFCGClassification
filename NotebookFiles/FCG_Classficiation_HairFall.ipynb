# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# continuous_feature_num 1
# discrete_feature_num 10
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
import experiment
scope_num = 30 
topology_ratio =6

experiment = experiment.Experiment() 
experiment.Ttest(dataread,scope_num,topology_ratio,nfolder =0)
# Out:
# Experiment number: 1
# self.random_dic {0: 116, 1: 15}
# accuracy_score_baseline 0.4882943143812709
# recall_score_baseline 0.4810707885304659
# precision_score_baseline 0.4776785714285714
# f1_score_baseline 0.46372428345349037
# accuracy_score_fcg 0.5284280936454849
# recall_score_fcg 0.5375224014336918
# precision_score_fcg 0.5494158602784989
# f1_score_fcg 0.502707102162143
# Experiment number: 2
# self.random_dic {0: 47, 1: 333}
# accuracy_score_baseline 0.47491638795986624
# recall_score_baseline 0.4721102150537634
# precision_score_baseline 0.4715024720747116
# f1_score_baseline 0.47027094124152247
# accuracy_score_fcg 0.4983277591973244
# recall_score_fcg 0.49789426523297486
# precision_score_fcg 0.4978959620377832
# f1_score_fcg 0.49787281683833406
# Experiment number: 3
# self.random_dic {0: 641, 1: 507}
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.510752688172043
# precision_score_baseline 0.5118882504458093
# f1_score_baseline 0.495531235750114
# accuracy_score_fcg 0.5183946488294314
# recall_score_fcg 0.5059139784946237
# precision_score_fcg 0.5109561752988048
# f1_score_fcg 0.4476600985221675
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# self.random_dic {0: 20, 1: 297}
# accuracy_score_baseline 0.5016722408026756
# recall_score_baseline 0.5067876344086022
# precision_score_baseline 0.5073443862710878
# f1_score_baseline 0.4943419783213211
# accuracy_score_fcg 0.4983277591973244
# recall_score_fcg 0.48237007168458784
# precision_score_fcg 0.42948028673835126
# f1_score_fcg 0.36987186692143414
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# self.random_dic {0: 570, 1: 395}
# accuracy_score_baseline 0.5284280936454849
# recall_score_baseline 0.5298835125448028
# precision_score_baseline 0.5300207039337475
# f1_score_baseline 0.5282381245454036
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 6
# self.random_dic {0: 487, 1: 511}
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5257616487455197
# precision_score_baseline 0.5494071146245059
# f1_score_baseline 0.4677244582043344
# accuracy_score_fcg 0.4983277591973244
# recall_score_fcg 0.49789426523297486
# precision_score_fcg 0.4978959620377832
# f1_score_fcg 0.49787281683833406
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Experiment number: 7
# self.random_dic {0: 458, 1: 354}
# accuracy_score_baseline 0.5418060200668896
# recall_score_baseline 0.5349014336917562
# precision_score_baseline 0.54066186449525
# f1_score_baseline 0.5212197716142455
# accuracy_score_fcg 0.4983277591973244
# recall_score_fcg 0.49789426523297486
# precision_score_fcg 0.4978959620377832
# f1_score_fcg 0.49787281683833406
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# self.random_dic {0: 431, 1: 417}
# accuracy_score_baseline 0.5117056856187291
# recall_score_baseline 0.5144937275985664
# precision_score_baseline 0.5148095586888848
# f1_score_baseline 0.5101220935452015
# accuracy_score_fcg 0.47157190635451507
# recall_score_fcg 0.48514784946236555
# precision_score_fcg 0.4673076923076923
# f1_score_fcg 0.3972389506991936
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# self.random_dic {0: 34, 1: 226}
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5393145161290323
# precision_score_baseline 0.5393356643356644
# f1_score_baseline 0.5384563758389261
# accuracy_score_fcg 0.4916387959866221
# recall_score_fcg 0.49932795698924737
# precision_score_fcg 0.4991867273910215
# f1_score_fcg 0.4724672671557248
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# self.random_dic {0: 172, 1: 252}
# accuracy_score_baseline 0.5484949832775919
# recall_score_baseline 0.5433243727598567
# precision_score_baseline 0.5470697040498442
# f1_score_baseline 0.536551201533922
# accuracy_score_fcg 0.48494983277591974
# recall_score_fcg 0.4884408602150538
# precision_score_fcg 0.4880211718822546
# f1_score_fcg 0.4818840579710145
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# self.random_dic {0: 469, 1: 417}
# accuracy_score_baseline 0.47491638795986624
# recall_score_baseline 0.48221326164874556
# precision_score_baseline 0.4788942052099947
# f1_score_baseline 0.45721223333526045
# accuracy_score_fcg 0.5083612040133779
# recall_score_fcg 0.519399641577061
# precision_score_fcg 0.5301952580195258
# f1_score_fcg 0.46623352966178877
# Experiment number: 12
# self.random_dic {0: 376, 1: 188}
# accuracy_score_baseline 0.5217391304347826
# recall_score_baseline 0.5162858422939068
# precision_score_baseline 0.5178448699067255
# f1_score_baseline 0.5079803454505702
# accuracy_score_fcg 0.5317725752508361
# recall_score_fcg 0.5338485663082437
# precision_score_fcg 0.5342195851073467
# f1_score_fcg 0.5311379928315413
# Experiment number: 13
# self.random_dic {0: 46, 1: 268}
# accuracy_score_baseline 0.5451505016722408
# recall_score_baseline 0.5336917562724015
# precision_score_baseline 0.5552616108171664
# f1_score_baseline 0.48914572864321615
# accuracy_score_fcg 0.5016722408026756
# recall_score_fcg 0.502105734767025
# precision_score_fcg 0.5021040379622168
# f1_score_fcg 0.5016499435104086
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Experiment number: 14
# self.random_dic {0: 12, 1: 608}
# accuracy_score_baseline 0.5284280936454849
# recall_score_baseline 0.5266801075268818
# precision_score_baseline 0.5268970189701897
# f1_score_baseline 0.526308693160751
# accuracy_score_fcg 0.5351170568561873
# recall_score_fcg 0.5351030465949821
# precision_score_fcg 0.5350559284116332
# f1_score_fcg 0.5349297823532704
# Experiment number: 15
# self.random_dic {0: 128, 1: 394}
# accuracy_score_baseline 0.5016722408026756
# recall_score_baseline 0.49668458781362
# precision_score_baseline 0.4964268469338484
# f1_score_baseline 0.48959156785243746
# accuracy_score_fcg 0.5016722408026756
# recall_score_fcg 0.4907706093189964
# precision_score_fcg 0.48581071772971485
# f1_score_fcg 0.44701793582821325
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# self.random_dic {0: 136, 1: 383}
# accuracy_score_baseline 0.4816053511705686
# recall_score_baseline 0.48127240143369177
# precision_score_baseline 0.48129251700680276
# f1_score_baseline 0.4812339792023462
# accuracy_score_fcg 0.5418060200668896
# recall_score_fcg 0.5280017921146953
# precision_score_fcg 0.5644728698163812
# f1_score_fcg 0.4572783761940724
# Not good accuracy result !!!!!
# Experiment number: 17
# self.random_dic {0: 508, 1: 609}
# accuracy_score_baseline 0.5183946488294314
# recall_score_baseline 0.5160170250896058
# precision_score_baseline 0.5162721893491125
# f1_score_baseline 0.5150040551500407
# accuracy_score_fcg 0.45484949832775917
# recall_score_fcg 0.4692652329749104
# precision_score_fcg 0.41970973782771537
# f1_score_fcg 0.36587428601168404
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# self.random_dic {0: 92, 1: 55}
# accuracy_score_baseline 0.5351170568561873
# recall_score_baseline 0.5262320788530466
# precision_score_baseline 0.5342517842517842
# f1_score_baseline 0.5011702293649555
# accuracy_score_fcg 0.5083612040133779
# recall_score_fcg 0.5090501792114696
# precision_score_fcg 0.5090501792114696
# f1_score_fcg 0.5083612040133779
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Experiment number: 19
# self.random_dic {0: 178, 1: 65}
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5023745519713262
# precision_score_baseline 0.502421418128655
# f1_score_baseline 0.5009473114399134
# accuracy_score_fcg 0.5083612040133779
# recall_score_fcg 0.5090501792114696
# precision_score_fcg 0.5090501792114696
# f1_score_fcg 0.5083612040133779
# Experiment number: 20
# self.random_dic {0: 253, 1: 635}
# accuracy_score_baseline 0.5250836120401338
# recall_score_baseline 0.5288754480286738
# precision_score_baseline 0.5300887021475257
# f1_score_baseline 0.5217401099396233
# accuracy_score_fcg 0.4882943143812709
# recall_score_fcg 0.4763888888888889
# precision_score_fcg 0.459579690136524
# f1_score_fcg 0.4209020595718825
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# self.random_dic {0: 346, 1: 325}
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49341397849462365
# precision_score_baseline 0.493360433604336
# f1_score_baseline 0.4911777877295118
# accuracy_score_fcg 0.4983277591973244
# recall_score_fcg 0.49740143369175627
# precision_score_fcg 0.49739840315780026
# f1_score_fcg 0.4973776223776224
# Experiment number: 22
# self.random_dic {0: 358, 1: 474}
# accuracy_score_baseline 0.4983277591973244
# recall_score_baseline 0.49887992831541217
# precision_score_baseline 0.49888042991491266
# f1_score_baseline 0.4983221476510067
# accuracy_score_fcg 0.4882943143812709
# recall_score_fcg 0.48747759856630823
# precision_score_fcg 0.48747086247086246
# f1_score_fcg 0.48746876995641797
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# self.random_dic {0: 336, 1: 511}
# accuracy_score_baseline 0.5551839464882943
# recall_score_baseline 0.5574148745519714
# precision_score_baseline 0.5581337325349301
# f1_score_baseline 0.5544663163673438
# accuracy_score_fcg 0.4983277591973244
# recall_score_fcg 0.49789426523297486
# precision_score_fcg 0.4978959620377832
# f1_score_fcg 0.49787281683833406
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# self.random_dic {0: 544, 1: 648}
# accuracy_score_baseline 0.5150501672240803
# recall_score_baseline 0.5076164874551972
# precision_score_baseline 0.509095773140717
# f1_score_baseline 0.49021106473043685
# accuracy_score_fcg 0.48494983277591974
# recall_score_fcg 0.496326164874552
# precision_score_fcg 0.494055386399884
# f1_score_fcg 0.43731058754521457
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# self.random_dic {0: 522, 1: 662}
# accuracy_score_baseline 0.5217391304347826
# recall_score_baseline 0.5138216845878136
# precision_score_baseline 0.5169598680593732
# f1_score_baseline 0.4940059880948155
# accuracy_score_fcg 0.47157190635451507
# recall_score_fcg 0.4747983870967742
# precision_score_fcg 0.4740160753880266
# f1_score_fcg 0.4689523381294964
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# self.random_dic {0: 387, 1: 109}
# accuracy_score_baseline 0.45819397993311034
# recall_score_baseline 0.4532706093189964
# precision_score_baseline 0.4498316498316498
# f1_score_baseline 0.44563724592565457
# accuracy_score_fcg 0.49498327759197325
# recall_score_fcg 0.49417562724014336
# precision_score_fcg 0.49417249417249415
# f1_score_fcg 0.49416852459751054
# Experiment number: 27
# self.random_dic {0: 641, 1: 529}
# accuracy_score_baseline 0.5016722408026756
# recall_score_baseline 0.4961917562724014
# precision_score_baseline 0.49582719685812465
# f1_score_baseline 0.48733616414080383
# accuracy_score_fcg 0.5518394648829431
# recall_score_fcg 0.5396505376344086
# precision_score_fcg 0.5710843373493976
# f1_score_fcg 0.4887975910993161
# Experiment number: 28
# self.random_dic {0: 191, 1: 373}
# accuracy_score_baseline 0.45819397993311034
# recall_score_baseline 0.45770609318996414
# precision_score_baseline 0.4577401736950488
# f1_score_baseline 0.4577026421854008
# accuracy_score_fcg 0.5016722408026756
# recall_score_fcg 0.502105734767025
# precision_score_fcg 0.5021040379622168
# f1_score_fcg 0.5016499435104086
# Experiment number: 29
# self.random_dic {0: 557, 1: 438}
# accuracy_score_baseline 0.49498327759197325
# recall_score_baseline 0.50625
# precision_score_baseline 0.509979968521963
# f1_score_baseline 0.44943600999939026
# accuracy_score_fcg 0.4916387959866221
# recall_score_fcg 0.4911962365591398
# precision_score_fcg 0.4912033306473274
# f1_score_fcg 0.4911777877295119
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Experiment number: 30
# self.random_dic {0: 76, 1: 327}
# accuracy_score_baseline 0.5384615384615384
# recall_score_baseline 0.5329077060931899
# precision_score_baseline 0.5362179487179487
# f1_score_baseline 0.52463133640553
# accuracy_score_fcg 0.4983277591973244
# recall_score_fcg 0.49789426523297486
# precision_score_fcg 0.4978959620377832
# f1_score_fcg 0.49787281683833406
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.5585284280936454
# max_recall_score_fcg 0.546594982078853
# max_precision_score_fcg 0.5809716599190284
# max_f1_score_fcg 0.5349297823532704
# all_accuracy_score_baseline mean 0.5115942028985507
# all_recall_score_baseline mean 0.5095400238948626
# all_precision_score_baseline mean 0.5118465542649628
# all_f1_score_baseline mean 0.49698138069391634
# all_accuracy_score_fcg mean 0.503567447045708
# all_recall_score_fcg mean 0.5030301672640382
# all_precision_score_fcg mean 0.5025190831662191
# all_f1_score_fcg mean 0.4756309702734434
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 0.4500797688961029
# Normal test + all_test_score_fcg_accuracy
# 0.06850329786539078
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  30.0  0.511594  0.026327  0.004807   0.501764
# 1       all_accuracy_score_fcg  30.0  0.503567  0.023232  0.004242   0.494892
# 2                     combined  60.0  0.507581  0.024947  0.003221   0.501136
#
#    Interval
# 0  0.521425
# 1  0.512243
# 2  0.514025
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.0080
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    1.2521
# 3                           Two side test p value =    0.2156
# 4                          Difference < 0 p value =    0.8922
# 5                          Difference > 0 p value =    0.1078
# 6                                       Cohen's d =    0.3233
# 7                                       Hedge's g =    0.3191
# 8                                  Glass's delta1 =    0.3049
# 9                                Point-Biserial r =    0.1622
# Normal test + all_test_score_baseline_recall
# 0.6389691829681396
# Normal test + all_test_score_fcg_recall
# 0.03564789891242981
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline  30.0  0.509540  0.025085  0.004580   0.500173
# 1       all_recall_score_fcg  30.0  0.503030  0.020189  0.003686   0.495491
# 2                   combined  60.0  0.506285  0.022813  0.002945   0.500392
#
#    Interval
# 0  0.518907
# 1  0.510569
# 2  0.512178
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.0065
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    1.1073
# 3                           Two side test p value =    0.2727
# 4                          Difference < 0 p value =    0.8636
# 5                          Difference > 0 p value =    0.1364
# 6                                       Cohen's d =    0.2859
# 7                                       Hedge's g =    0.2822
# 8                                  Glass's delta1 =    0.2595
# 9                                Point-Biserial r =    0.1439
# Normal test + all_test_score_baseline_precision
# 0.7043865323066711
# Normal test + all_test_score_fcg_precision
# 0.06499515473842621
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_baseline  30.0  0.511847  0.028195  0.005148
# 1       all_precision_score_fcg  30.0  0.502519  0.035766  0.006530
# 2                      combined  60.0  0.507183  0.032274  0.004167
#
#    95% Conf.  Interval
# 0   0.501319  0.522375
# 1   0.489164  0.515874
# 2   0.498846  0.515520
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...   0.0093
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    1.1218
# 3                           Two side test p value =    0.2666
# 4                          Difference < 0 p value =    0.8667
# 5                          Difference > 0 p value =    0.1333
# 6                                       Cohen's d =    0.2896
# 7                                       Hedge's g =    0.2859
# 8                                  Glass's delta1 =    0.3308
# 9                                Point-Biserial r =    0.1457
# Normal test + all_test_score_baseline_f1
# 0.7968895435333252
# Normal test + all_test_score_fcg_f1
# 0.00070590601535514
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.496981  0.027728  0.005063   0.486627
# 1       all_f1_score_fcg  30.0  0.475631  0.042011  0.007670   0.459944
# 2               combined  60.0  0.486306  0.036896  0.004763   0.476775
#
#    Interval
# 0  0.507335
# 1  0.491318
# 2  0.495837
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0214
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    2.3232
# 3                           Two side test p value =    0.0237
# 4                          Difference < 0 p value =    0.9882
# 5                          Difference > 0 p value =    0.0118
# 6                                       Cohen's d =    0.5998
# 7                                       Hedge's g =    0.5920
# 8                                  Glass's delta1 =    0.7700
# 9                                Point-Biserial r =    0.2918

# %%
import experiment_M
scope_num =30
topology_ratio =6


dic ={0: 570, 1: 395}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.4782608695652174
# recall_score_baseline 0.4869175627240143
# precision_score_baseline 0.48319907940161105
# f1_score_baseline 0.45238095238095233
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 2
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5004032258064517
# precision_score_baseline 0.500429717341482
# f1_score_baseline 0.494563230994152
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 3
# accuracy_score_baseline 0.5117056856187291
# recall_score_baseline 0.5071012544802866
# precision_score_baseline 0.5075677998472116
# f1_score_baseline 0.5013934576023391
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 4
# accuracy_score_baseline 0.5217391304347826
# recall_score_baseline 0.5143145161290323
# precision_score_baseline 0.5170947030497592
# f1_score_baseline 0.49724263625139636
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 5
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5134632616487456
# precision_score_baseline 0.5170177823083022
# f1_score_baseline 0.4820207884633392
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 6
# accuracy_score_baseline 0.48494983277591974
# recall_score_baseline 0.4827732974910395
# precision_score_baseline 0.48255761204863
# f1_score_baseline 0.4818840579710145
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 7
# accuracy_score_baseline 0.5351170568561873
# recall_score_baseline 0.525
# precision_score_baseline 0.5358980957282553
# f1_score_baseline 0.49102955043658225
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 8
# accuracy_score_baseline 0.49498327759197325
# recall_score_baseline 0.5015681003584229
# precision_score_baseline 0.5017959770114943
# f1_score_baseline 0.4816239365305349
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 9
# accuracy_score_baseline 0.5250836120401338
# recall_score_baseline 0.5170474910394265
# precision_score_baseline 0.5210686600221484
# f1_score_baseline 0.4967045993361783
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 10
# accuracy_score_baseline 0.5150501672240803
# recall_score_baseline 0.5113127240143369
# precision_score_baseline 0.5117880485527544
# f1_score_baseline 0.5079166903126952
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 11
# accuracy_score_baseline 0.48494983277591974
# recall_score_baseline 0.4891801075268817
# precision_score_baseline 0.4885869565217391
# f1_score_baseline 0.48005871725383914
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 12
# accuracy_score_baseline 0.5451505016722408
# recall_score_baseline 0.5482302867383513
# precision_score_baseline 0.5494942528735631
# f1_score_baseline 0.5433063791554358
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_baseline 0.44481605351170567
# recall_score_baseline 0.4443100358422939
# precision_score_baseline 0.44435491091413737
# f1_score_baseline 0.4443125839677564
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 14
# accuracy_score_baseline 0.5016722408026756
# recall_score_baseline 0.5040770609318996
# precision_score_baseline 0.5041420118343195
# f1_score_baseline 0.5005773218989966
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 15
# accuracy_score_baseline 0.4414715719063545
# recall_score_baseline 0.4423163082437276
# precision_score_baseline 0.44224903561496365
# f1_score_baseline 0.4414465809814647
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 16
# accuracy_score_baseline 0.4882943143812709
# recall_score_baseline 0.49092741935483875
# precision_score_baseline 0.49074835526315785
# f1_score_baseline 0.48682483594144366
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 17
# accuracy_score_baseline 0.5050167224080268
# recall_score_baseline 0.5070564516129032
# precision_score_baseline 0.5071337983512999
# f1_score_baseline 0.5043458781362007
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_baseline 0.5016722408026756
# recall_score_baseline 0.5053091397849462
# precision_score_baseline 0.5055167597765363
# f1_score_baseline 0.4984407542921475
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 19
# accuracy_score_baseline 0.5284280936454849
# recall_score_baseline 0.5224910394265233
# precision_score_baseline 0.5251025102510252
# f1_score_baseline 0.5125281840781638
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 20
# accuracy_score_baseline 0.4983277591973244
# recall_score_baseline 0.49592293906810037
# precision_score_baseline 0.4958579881656805
# f1_score_baseline 0.4947958907812922
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 21
# accuracy_score_baseline 0.5250836120401338
# recall_score_baseline 0.5175403225806452
# precision_score_baseline 0.5210846617837139
# f1_score_baseline 0.499976446203128
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 22
# accuracy_score_baseline 0.5250836120401338
# recall_score_baseline 0.5202508960573476
# precision_score_baseline 0.5217412217412217
# f1_score_baseline 0.5140770921076726
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 23
# accuracy_score_baseline 0.46153846153846156
# recall_score_baseline 0.46512096774193545
# precision_score_baseline 0.46375698324022346
# f1_score_baseline 0.4580467210807768
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 24
# accuracy_score_baseline 0.47157190635451507
# recall_score_baseline 0.4762768817204301
# precision_score_baseline 0.4746262219666475
# f1_score_baseline 0.4650557115680768
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 25
# accuracy_score_baseline 0.5183946488294314
# recall_score_baseline 0.5110887096774194
# precision_score_baseline 0.513157894736842
# f1_score_baseline 0.4945054945054944
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 26
# accuracy_score_baseline 0.45484949832775917
# recall_score_baseline 0.4530017921146953
# precision_score_baseline 0.45261969286359527
# f1_score_baseline 0.45239941124257027
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 27
# accuracy_score_baseline 0.5016722408026756
# recall_score_baseline 0.5099910394265234
# precision_score_baseline 0.5125323142632348
# f1_score_baseline 0.47928281730308453
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Experiment number: 28
# accuracy_score_baseline 0.5083612040133779
# recall_score_baseline 0.5070788530465951
# precision_score_baseline 0.5071043165467626
# f1_score_baseline 0.5069493521790343
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 29
# accuracy_score_baseline 0.5418060200668896
# recall_score_baseline 0.5388440860215054
# precision_score_baseline 0.5398620689655172
# f1_score_baseline 0.5371464729212099
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# Not good accuracy result !!!!!
# Experiment number: 30
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49094982078853044
# precision_score_baseline 0.49094982078853044
# f1_score_baseline 0.49094982078853044
# accuracy_score_fcg 0.5585284280936454
# recall_score_fcg 0.546594982078853
# precision_score_fcg 0.5809716599190284
# f1_score_fcg 0.4990862016448371
# max_accuracy_score_fcg 0.5585284280936454
# max_recall_score_fcg 0.546594982078853
# max_precision_score_fcg 0.5809716599190284
# max_f1_score_fcg 0.4990862016448371
# all_accuracy_score_baseline mean 0.5005574136008918
# all_recall_score_baseline mean 0.4999955197132617
# all_precision_score_baseline mean 0.5009679750591453
# all_f1_score_baseline mean 0.48972621222218343
# all_accuracy_score_fcg mean 0.5585284280936453
# all_recall_score_fcg mean 0.5465949820788529
# all_precision_score_fcg mean 0.5809716599190284
# all_f1_score_fcg mean 0.49908620164483725
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 0.3462403118610382
# Normal test + all_test_score_fcg_accuracy
# 1.0
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.500557  2.690440e-02  4.912050e-03
# 1       all_accuracy_score_fcg  30.0  0.558528  1.129203e-16  2.061632e-17
# 2                     combined  60.0  0.529543  3.478777e-02  4.491082e-03
#
#    95% Conf.  Interval
# 0   0.490511  0.510604
# 1   0.558528  0.558528
# 2   0.520556  0.538530
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0580
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -11.8018
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.0472
# 7                                       Hedge's g =   -3.0076
# 8                                  Glass's delta1 =   -2.1547
# 9                                Point-Biserial r =   -0.8402
# Normal test + all_test_score_baseline_recall
# 0.08960116654634476
# Normal test + all_test_score_fcg_recall
# 1.0
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.499996  2.497702e-02  4.560160e-03
# 1       all_recall_score_fcg  30.0  0.546595  1.129203e-16  2.061632e-17
# 2                   combined  60.0  0.523295  2.930389e-02  3.783115e-03
#
#    95% Conf.  Interval
# 0   0.490669  0.509322
# 1   0.546595  0.546595
# 2   0.515725  0.530865
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0466
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -10.2188
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.6385
# 7                                       Hedge's g =   -2.6042
# 8                                  Glass's delta1 =   -1.8657
# 9                                Point-Biserial r =   -0.8018
# Normal test + all_test_score_baseline_precision
# 0.21390283107757568
# Normal test + all_test_score_fcg_precision
# 1.0
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_baseline  30.0  0.500968  0.026318  0.004805
# 1       all_precision_score_fcg  30.0  0.580972  0.000000  0.000000
# 2                      combined  60.0  0.540970  0.044359  0.005727
#
#    95% Conf.  Interval
# 0   0.491141  0.510795
# 1        NaN       NaN
# 2   0.529511  0.552429
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0800
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -16.6502
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -4.2991
# 7                                       Hedge's g =   -4.2432
# 8                                  Glass's delta1 =   -3.0399
# 9                                Point-Biserial r =   -0.9094
# Normal test + all_test_score_baseline_f1
# 0.21113009750843048
# Normal test + all_test_score_fcg_f1
# 1.0
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.489726  2.412600e-02  4.404785e-03
# 1       all_f1_score_fcg  30.0  0.499086  1.693804e-16  3.092449e-17
# 2               combined  60.0  0.494406  1.756055e-02  2.267057e-03
#
#    95% Conf.  Interval
# 0   0.480717  0.498735
# 1   0.499086  0.499086
# 2   0.489870  0.498943
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0094
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -2.1250
# 3                           Two side test p value =    0.0379
# 4                          Difference < 0 p value =    0.0189
# 5                          Difference > 0 p value =    0.9811
# 6                                       Cohen's d =   -0.5487
# 7                                       Hedge's g =   -0.5415
# 8                                  Glass's delta1 =   -0.3880
# 9                                Point-Biserial r =   -0.2688
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
