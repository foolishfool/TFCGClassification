# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("student_data.csv")
#csv = csv.drop(columns=['CLIENTNUM'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"school")
dataread.label_encoding(csv,"sex")
dataread.label_encoding(csv,"address")
dataread.label_encoding(csv,"famsize")
dataread.label_encoding(csv,"Pstatus")
dataread.label_encoding(csv,"Mjob")
dataread.label_encoding(csv,"Fjob")
dataread.label_encoding(csv,"reason")
dataread.label_encoding(csv,"guardian")
dataread.label_encoding(csv,"schoolsup")
dataread.label_encoding(csv,"famsup")
dataread.label_encoding(csv,"paid")
dataread.label_encoding(csv,"activities")
dataread.label_encoding(csv,"nursery")
dataread.label_encoding(csv,"higher")
dataread.label_encoding(csv,"internet")
dataread.label_encoding(csv,"romantic")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"reason")
# Out:
# continuous_feature_num 1
# discrete_feature_num 31
# self.data_discrete_indexes ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'G1', 'G2', 'G3']

# %%
import experiment
scope_num = 30
topology_ratio =7

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# self.random_dic {0: 86, 2: 249, 1: 24, 3: 216}
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.30636448637851166
# precision_score_baseline 0.31788194444444445
# f1_score_baseline 0.3064448340537652
# accuracy_score_fcg 0.3728813559322034
# recall_score_fcg 0.3275149815121764
# precision_score_fcg 0.40784313725490196
# f1_score_fcg 0.32429663871871117
# Experiment number: 2
# self.random_dic {0: 161, 2: 19, 1: 141, 3: 8}
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.30636448637851166
# precision_score_baseline 0.31788194444444445
# f1_score_baseline 0.3064448340537652
# accuracy_score_fcg 0.3305084745762712
# recall_score_fcg 0.278635938628926
# precision_score_fcg 0.2866300366300366
# f1_score_fcg 0.26108749299538775
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# ...

# %%
import experiment_M
scope_num =3
topology_ratio =7


dic= {0: 86, 2: 249, 1: 24, 3: 216}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.30636448637851166
# precision_score_baseline 0.31788194444444445
# f1_score_baseline 0.3064448340537652
# accuracy_score_fcg 0.3728813559322034
# recall_score_fcg 0.3275149815121764
# precision_score_fcg 0.40784313725490196
# f1_score_fcg 0.32429663871871117
# Experiment number: 2
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.30636448637851166
# precision_score_baseline 0.31788194444444445
# f1_score_baseline 0.3064448340537652
# accuracy_score_fcg 0.3728813559322034
# recall_score_fcg 0.3275149815121764
# precision_score_fcg 0.40784313725490196
# f1_score_fcg 0.32429663871871117
# Experiment number: 3
# accuracy_score_baseline 0.3559322033898305
# recall_score_baseline 0.30636448637851166
# precision_score_baseline 0.31788194444444445
# f1_score_baseline 0.3064448340537652
# accuracy_score_fcg 0.3728813559322034
# recall_score_fcg 0.3275149815121764
# ...
