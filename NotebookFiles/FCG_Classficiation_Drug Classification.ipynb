# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("drug200.csv")
#csv = csv.drop(columns=['ID'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"BP")
dataread.label_encoding(csv,"Cholesterol")
dataread.label_encoding(csv,"Drug")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Drug")
# Out:
# continuous_feature_num 2
# discrete_feature_num 3
# self.data_discrete_indexes ['Sex', 'BP', 'Cholesterol']

# %%
import experiment
scope_num = 30
topology_ratio =3


experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio,nfolder = 0)
# Out:
# Experiment number: 1
# self.random_dic {0: 130, 3: 34, 4: 114, 1: 102, 2: 52}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.35
# recall_score_fcg 0.5633333333333332
# precision_score_fcg 0.26269905533063426
# f1_score_fcg 0.34780578898225956
# Not good accuracy result !!!!!
# Experiment number: 2
# self.random_dic {0: 16, 3: 1, 4: 53, 1: 66, 2: 33}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.45
# precision_score_fcg 0.3169298245614035
# f1_score_fcg 0.3309803921568627
# Not good accuracy result !!!!!
# Experiment number: 3
# self.random_dic {0: 124, 3: 133, 4: 28, 1: 92, 2: 84}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.4766666666666667
# precision_score_fcg 0.4163369963369963
# f1_score_fcg 0.3562566844919786
# Not good accuracy result !!!!!
# Experiment number: 4
# self.random_dic {0: 119, 3: 105, 4: 63, 1: 120, 2: 93}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.26666666666666666
# recall_score_fcg 0.43666666666666665
# precision_score_fcg 0.3158608058608058
# f1_score_fcg 0.2813415095768037
# Not good accuracy result !!!!!
# Experiment number: 5
# self.random_dic {0: 25, 3: 1, 4: 37, 1: 122, 2: 84}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.38333333333333336
# recall_score_fcg 0.5366666666666667
# precision_score_fcg 0.4317216117216117
# f1_score_fcg 0.3828860028860029
# Not good accuracy result !!!!!
# Experiment number: 6
# self.random_dic {0: 130, 3: 136, 4: 70, 1: 29, 2: 33}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.38333333333333336
# recall_score_fcg 0.5166666666666667
# precision_score_fcg 0.43346153846153845
# f1_score_fcg 0.3676190476190476
# Not good accuracy result !!!!!
# Experiment number: 7
# self.random_dic {0: 12, 3: 10, 4: 78, 1: 132, 2: 44}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.38333333333333336
# recall_score_fcg 0.5366666666666667
# precision_score_fcg 0.4317216117216117
# f1_score_fcg 0.3828860028860029
# Not good accuracy result !!!!!
# Experiment number: 8
# self.random_dic {0: 15, 3: 4, 4: 27, 1: 22, 2: 84}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.26666666666666666
# recall_score_fcg 0.37
# precision_score_fcg 0.3425
# f1_score_fcg 0.25649122807017544
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# self.random_dic {0: 25, 3: 136, 4: 53, 1: 102, 2: 97}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.2833333333333333
# recall_score_fcg 0.45666666666666667
# precision_score_fcg 0.26776556776556776
# f1_score_fcg 0.29771660388293253
# Not good accuracy result !!!!!
# Experiment number: 10
# self.random_dic {0: 25, 3: 1, 4: 99, 1: 67, 2: 52}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.2833333333333333
# recall_score_fcg 0.45666666666666667
# precision_score_fcg 0.26776556776556776
# f1_score_fcg 0.29771660388293253
# Not good accuracy result !!!!!
# Experiment number: 11
# self.random_dic {0: 12, 3: 133, 4: 23, 1: 66, 2: 35}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.4766666666666667
# precision_score_fcg 0.4163369963369963
# f1_score_fcg 0.3562566844919786
# Not good accuracy result !!!!!
# Experiment number: 12
# self.random_dic {0: 16, 3: 136, 4: 114, 1: 120, 2: 35}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.35
# recall_score_fcg 0.41
# precision_score_fcg 0.2673144399460189
# f1_score_fcg 0.28117647058823525
# Not good accuracy result !!!!!
# Experiment number: 13
# self.random_dic {0: 7, 3: 30, 4: 8, 1: 102, 2: 52}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.55
# precision_score_fcg 0.4384615384615385
# f1_score_fcg 0.3974436090225564
# Not good accuracy result !!!!!
# Experiment number: 14
# self.random_dic {0: 129, 3: 135, 4: 114, 1: 49, 2: 108}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.4
# recall_score_fcg 0.53
# precision_score_fcg 0.41692982456140354
# f1_score_fcg 0.37669467787114846
# Not good accuracy result !!!!!
# Experiment number: 15
# self.random_dic {0: 86, 3: 54, 4: 3, 1: 116, 2: 108}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.3333333333333333
# recall_score_fcg 0.4766666666666667
# precision_score_fcg 0.3426373626373626
# f1_score_fcg 0.3734973347799424
# Not good accuracy result !!!!!
# Experiment number: 16
# self.random_dic {0: 39, 3: 133, 4: 101, 1: 95, 2: 52}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.3
# recall_score_fcg 0.51
# precision_score_fcg 0.3502930402930403
# f1_score_fcg 0.3232900432900433
# Not good accuracy result !!!!!
# Experiment number: 17
# self.random_dic {0: 86, 3: 135, 4: 63, 1: 100, 2: 103}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.3
# recall_score_fcg 0.5033333333333333
# precision_score_fcg 0.37576923076923074
# f1_score_fcg 0.32173767752715116
# Not good accuracy result !!!!!
# Experiment number: 18
# self.random_dic {0: 0, 3: 34, 4: 55, 1: 80, 2: 103}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5700000000000001
# precision_score_fcg 0.37769905533063425
# f1_score_fcg 0.3745915032679739
# Not good accuracy result !!!!!
# Experiment number: 19
# self.random_dic {0: 0, 3: 1, 4: 109, 1: 92, 2: 84}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.3333333333333333
# recall_score_fcg 0.47000000000000003
# precision_score_fcg 0.33731443994601884
# f1_score_fcg 0.3152149321266968
# Not good accuracy result !!!!!
# Experiment number: 20
# self.random_dic {0: 111, 3: 136, 4: 26, 1: 38, 2: 41}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.35
# recall_score_fcg 0.5633333333333332
# precision_score_fcg 0.26269905533063426
# f1_score_fcg 0.34780578898225956
# Not good accuracy result !!!!!
# Experiment number: 21
# self.random_dic {0: 60, 3: 34, 4: 94, 1: 132, 2: 93}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.3333333333333333
# recall_score_fcg 0.47000000000000003
# precision_score_fcg 0.33731443994601884
# f1_score_fcg 0.3152149321266968
# Not good accuracy result !!!!!
# Experiment number: 22
# self.random_dic {0: 134, 3: 135, 4: 26, 1: 9, 2: 44}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.5700000000000001
# precision_score_fcg 0.37769905533063425
# f1_score_fcg 0.3745915032679739
# Not good accuracy result !!!!!
# Experiment number: 23
# self.random_dic {0: 12, 3: 133, 4: 139, 1: 92, 2: 52}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.4
# recall_score_fcg 0.4966666666666667
# precision_score_fcg 0.4151214574898785
# f1_score_fcg 0.41395532125893836
# Not good accuracy result !!!!!
# Experiment number: 24
# self.random_dic {0: 106, 3: 34, 4: 20, 1: 22, 2: 35}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.38333333333333336
# recall_score_fcg 0.5233333333333333
# precision_score_fcg 0.3756477732793522
# f1_score_fcg 0.40275541795665637
# Not good accuracy result !!!!!
# Experiment number: 25
# self.random_dic {0: 69, 3: 133, 4: 20, 1: 9, 2: 108}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.4
# recall_score_fcg 0.53
# precision_score_fcg 0.41692982456140354
# f1_score_fcg 0.37669467787114846
# Not good accuracy result !!!!!
# Experiment number: 26
# self.random_dic {0: 127, 3: 4, 4: 63, 1: 80, 2: 103}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.35
# recall_score_fcg 0.5566666666666668
# precision_score_fcg 0.3942307692307692
# f1_score_fcg 0.365515873015873
# Not good accuracy result !!!!!
# Experiment number: 27
# self.random_dic {0: 104, 3: 30, 4: 37, 1: 122, 2: 35}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.2833333333333333
# recall_score_fcg 0.44333333333333336
# precision_score_fcg 0.3603846153846154
# f1_score_fcg 0.295108359133127
# Not good accuracy result !!!!!
# Experiment number: 28
# self.random_dic {0: 96, 3: 10, 4: 42, 1: 49, 2: 108}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.2833333333333333
# recall_score_fcg 0.44333333333333336
# precision_score_fcg 0.3603846153846154
# f1_score_fcg 0.295108359133127
# Not good accuracy result !!!!!
# Experiment number: 29
# self.random_dic {0: 5, 3: 135, 4: 137, 1: 116, 2: 97}
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 30
# self.random_dic {0: 12, 3: 30, 4: 21, 1: 122, 2: 73}
# accuracy_score_baseline 0.45
# recall_score_baseline 0.3466666666666667
# precision_score_baseline 0.25141700404858297
# f1_score_baseline 0.2808654496281271
# accuracy_score_fcg 0.36666666666666664
# recall_score_fcg 0.4766666666666667
# precision_score_fcg 0.4163369963369963
# f1_score_fcg 0.3562566844919786
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.4166666666666667
# max_recall_score_fcg 0.5700000000000001
# max_precision_score_fcg 0.4384615384615385
# max_f1_score_fcg 0.41395532125893836
# all_accuracy_score_baseline mean 0.4499999999999999
# all_recall_score_baseline mean 0.34666666666666685
# all_precision_score_baseline mean 0.2514170040485829
# all_f1_score_baseline mean 0.2808654496281271
# all_accuracy_score_fcg mean 0.34777777777777774
# all_recall_score_fcg mean 0.4954444444444445
# all_precision_score_fcg mean 0.3636065644881435
# all_f1_score_fcg mean 0.34418048893996256
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 0.03383998945355415
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.450000  1.129203e-16  2.061632e-17
# 1       all_accuracy_score_fcg  30.0  0.347778  4.542969e-02  8.294289e-03
# 2                     combined  60.0  0.398889  6.058928e-02  7.822042e-03
#
#    95% Conf.  Interval
# 0   0.450000  0.450000
# 1   0.330814  0.364742
# 2   0.383237  0.414541
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  1.022000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   1.232440e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   3.182100e+00
# 7                                       Hedge's g =   3.140800e+00
# 8                                  Glass's delta1 =   9.052603e+14
# 9                                Point-Biserial r =   8.507000e-01
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 0.3667701482772827
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.346667  1.693804e-16  3.092449e-17
# 1       all_recall_score_fcg  30.0  0.495444  5.053343e-02  9.226099e-03
# 2                   combined  60.0  0.421056  8.296187e-02  1.071033e-02
#
#    95% Conf.  Interval
# 0   0.346667  0.346667
# 1   0.476575  0.514314
# 2   0.399624  0.442487
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -1.488000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.612580e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.163700e+00
# 7                                       Hedge's g =  -4.109600e+00
# 8                                  Glass's delta1 =  -8.783649e+14
# 9                                Point-Biserial r =  -9.042000e-01
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 0.012018272653222084
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.251417  5.646013e-17  1.030816e-17
# 1       all_precision_score_fcg  30.0  0.363607  5.673288e-02  1.035796e-02
# 2                      combined  60.0  0.307512  6.915194e-02  8.927477e-03
#
#    95% Conf.  Interval
# 0   0.251417  0.251417
# 1   0.342422  0.384791
# 2   0.289648  0.325376
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all... -1.122000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.083120e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.796600e+00
# 7                                       Hedge's g =  -2.760300e+00
# 8                                  Glass's delta1 =  -1.987058e+15
# 9                                Point-Biserial r =  -8.180000e-01
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 0.24248531460762024
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.280865  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  30.0  0.344180  0.040783  0.007446   0.328952
# 2               combined  60.0  0.312523  0.042857  0.005533   0.301452
#
#    Interval
# 0       NaN
# 1  0.359409
# 2  0.323594
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0633
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -8.5033
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.1955
# 7                                       Hedge's g =   -2.1670
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7449
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment_M
scope_num = 30
topology_ratio =3


dic= {0: 5, 3: 135, 4: 137, 1: 116, 2: 97}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 2
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 3
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 4
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 5
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 7
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 8
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 9
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 10
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 11
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 12
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 14
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 15
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 16
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 17
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 19
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 20
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 21
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 22
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 23
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 24
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 25
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 26
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 27
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 28
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 29
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# Experiment number: 30
# accuracy_score_baseline 0.45
# recall_score_baseline 0.4133333333333333
# precision_score_baseline 0.3505016722408027
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_baseline 0.3529824561403509
# accuracy_score_fcg 0.4166666666666667
# recall_score_fcg 0.49333333333333335
# precision_score_fcg 0.38192982456140345
# f1_score_fcg 0.36080495356037157
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.4166666666666667
# max_recall_score_fcg 0.49333333333333335
# max_precision_score_fcg 0.38192982456140345
# max_f1_score_fcg 0.36080495356037157
# all_accuracy_score_baseline mean 0.4499999999999999
# all_recall_score_baseline mean 0.4133333333333334
# all_precision_score_baseline mean 0.35050167224080275
# all_f1_score_baseline mean 0.35298245614035095
# all_accuracy_score_fcg mean 0.4166666666666666
# all_recall_score_fcg mean 0.49333333333333346
# all_precision_score_fcg mean 0.38192982456140345
# all_f1_score_fcg mean 0.3608049535603717
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 1.0
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.450000  1.129203e-16  2.061632e-17
# 1       all_accuracy_score_fcg  30.0  0.416667  1.129203e-16  2.061632e-17
# 2                     combined  60.0  0.433333  1.680732e-02  2.169815e-03
#
#    95% Conf.  Interval
# 0   0.450000  0.450000
# 1   0.416667  0.416667
# 2   0.428992  0.437675
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  3.330000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   1.143280e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   2.951936e+14
# 7                                       Hedge's g =   2.913599e+14
# 8                                  Glass's delta1 =   2.951936e+14
# 9                                Point-Biserial r =   1.000000e+00
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 1.0
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.413333  1.129203e-16  2.061632e-17
# 1       all_recall_score_fcg  30.0  0.493333  1.129203e-16  2.061632e-17
# 2                   combined  60.0  0.453333  4.033756e-02  5.207556e-03
#
#    95% Conf.  Interval
# 0   0.413333  0.413333
# 1   0.493333  0.493333
# 2   0.442913  0.463754
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -8.000000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -2.743871e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.084646e+14
# 7                                       Hedge's g =  -6.992637e+14
# 8                                  Glass's delta1 =  -7.084646e+14
# 9                                Point-Biserial r =  -1.000000e+00
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 1.0
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.350502  5.646013e-17  1.030816e-17
# 1       all_precision_score_fcg  30.0  0.381930  0.000000e+00  0.000000e+00
# 2                      combined  60.0  0.366216  1.584669e-02  2.045798e-03
#
#    95% Conf.  Interval
# 0   0.350502  0.350502
# 1        NaN       NaN
# 2   0.362122  0.370309
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all... -3.140000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -3.048861e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.872125e+14
# 7                                       Hedge's g =  -7.769890e+14
# 8                                  Glass's delta1 =  -5.566433e+14
# 9                                Point-Biserial r =  -1.000000e+00
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 1.0
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.352982  5.646013e-17  1.030816e-17
# 1       all_f1_score_fcg  30.0  0.360805  1.129203e-16  2.061632e-17
# 2               combined  60.0  0.356894  3.944256e-03  5.092012e-04
#
#    95% Conf.  Interval
# 0   0.352982  0.352982
# 1   0.360805  0.360805
# 2   0.355875  0.357913
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco... -7.800000e-03
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -3.393745e+14
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -8.762612e+13
# 7                                       Hedge's g =  -8.648811e+13
# 8                                  Glass's delta1 =  -1.385491e+14
# 9                                Point-Biserial r =  -1.000000e+00
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
