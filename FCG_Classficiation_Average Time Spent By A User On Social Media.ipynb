# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# continuous_feature_num 2
# discrete_feature_num 9
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
import experiment
scope_num = 30
topology_ratio =4


experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio,nfolder =0)
# Out:
# Experiment number: 1
# self.random_dic {3: 81, 2: 333, 5: 6, 8: 659, 6: 241, 7: 116, 4: 177, 1: 106, 9: 15}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.10666666666666667
# recall_score_fcg 0.10423437573975208
# precision_score_fcg 0.09532370316684041
# f1_score_fcg 0.09029221750120395
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# self.random_dic {3: 262, 2: 375, 5: 543, 8: 20, 6: 686, 7: 62, 4: 442, 1: 35, 9: 255}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.13959793690976488
# precision_score_fcg 0.11755348920171602
# f1_score_fcg 0.12514157120847028
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# self.random_dic {3: 669, 2: 194, 5: 392, 8: 684, 6: 98, 7: 129, 4: 455, 1: 215, 9: 33}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.1
# recall_score_fcg 0.10706253851415143
# precision_score_fcg 0.11046000761260778
# f1_score_fcg 0.09573113665088313
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# self.random_dic {3: 341, 2: 562, 5: 186, 8: 421, 6: 363, 7: 661, 4: 696, 1: 215, 9: 516}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.11333333333333333
# recall_score_fcg 0.11465681788262433
# precision_score_fcg 0.10828503294199822
# f1_score_fcg 0.10243952707620352
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# self.random_dic {3: 243, 2: 165, 5: 124, 8: 187, 6: 121, 7: 22, 4: 118, 1: 176, 9: 30}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.09
# recall_score_fcg 0.09674114674114674
# precision_score_fcg 0.09393773275216573
# f1_score_fcg 0.07982483040233573
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# self.random_dic {3: 235, 2: 1, 5: 278, 8: 189, 6: 404, 7: 297, 4: 678, 1: 552, 9: 662}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.09
# recall_score_fcg 0.08751907407821385
# precision_score_fcg 0.07146697627703902
# f1_score_fcg 0.07137719942625544
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# self.random_dic {3: 119, 2: 227, 5: 26, 8: 426, 6: 303, 7: 128, 4: 425, 1: 536, 9: 271}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.14333333333333334
# recall_score_fcg 0.14960979853452971
# precision_score_fcg 0.17885944328633566
# f1_score_fcg 0.1453059633398794
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Experiment number: 8
# self.random_dic {3: 360, 2: 222, 5: 344, 8: 684, 6: 404, 7: 385, 4: 517, 1: 105, 9: 592}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.12914142053927
# precision_score_fcg 0.12866009407724124
# f1_score_fcg 0.12293896948288803
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# self.random_dic {3: 108, 2: 435, 5: 612, 8: 337, 6: 466, 7: 159, 4: 390, 1: 14, 9: 504}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.15666666666666668
# recall_score_fcg 0.15936706877567092
# precision_score_fcg 0.15458461425852732
# f1_score_fcg 0.14236614154850608
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Experiment number: 10
# self.random_dic {3: 569, 2: 200, 5: 668, 8: 414, 6: 403, 7: 54, 4: 182, 1: 35, 9: 206}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.11
# recall_score_fcg 0.1089195820378616
# precision_score_fcg 0.08956126859537958
# f1_score_fcg 0.0968533765919387
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# self.random_dic {3: 369, 2: 601, 5: 312, 8: 109, 6: 445, 7: 359, 4: 670, 1: 181, 9: 372}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# self.random_dic {3: 122, 2: 110, 5: 624, 8: 462, 6: 237, 7: 676, 4: 61, 1: 215, 9: 647}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.11366440694397682
# precision_score_fcg 0.12896116313808972
# f1_score_fcg 0.09321904980315712
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# self.random_dic {3: 606, 2: 151, 5: 26, 8: 684, 6: 134, 7: 534, 4: 253, 1: 609, 9: 519}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.16666666666666666
# recall_score_fcg 0.16693117660859597
# precision_score_fcg 0.1616363255526344
# f1_score_fcg 0.1458660560600573
# Experiment number: 27
# self.random_dic {3: 97, 2: 200, 5: 644, 8: 352, 6: 273, 7: 275, 4: 696, 1: 258, 9: 551}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.10666666666666667
# recall_score_fcg 0.11770591743710024
# precision_score_fcg 0.10454807846098692
# f1_score_fcg 0.10248365507026178
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# self.random_dic {3: 262, 2: 50, 5: 532, 8: 597, 6: 490, 7: 546, 4: 174, 1: 183, 9: 638}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.12333333333333334
# recall_score_fcg 0.12471480616641904
# precision_score_fcg 0.1285179711531704
# f1_score_fcg 0.1193478861905687
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# self.random_dic {3: 251, 2: 368, 5: 612, 8: 643, 6: 363, 7: 54, 4: 27, 1: 215, 9: 367}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.12
# recall_score_fcg 0.12193702838864127
# precision_score_fcg 0.12321810234853715
# f1_score_fcg 0.11894654980330104
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# self.random_dic {3: 674, 2: 281, 5: 436, 8: 663, 6: 579, 7: 418, 4: 521, 1: 332, 9: 104}
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.13666666666666666
# recall_score_fcg 0.1338678196205078
# precision_score_fcg 0.11445399411482206
# f1_score_fcg 0.11545086220243655
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.16666666666666666
# max_recall_score_fcg 0.16693117660859597
# max_precision_score_fcg 0.17885944328633566
# max_f1_score_fcg 0.1458660560600573
# all_accuracy_score_baseline mean 0.15333333333333332
# all_recall_score_baseline mean 0.1625205738108964
# all_precision_score_baseline mean 0.1568583510325797
# all_f1_score_baseline mean 0.13822544173607637
# all_accuracy_score_fcg mean 0.11866666666666667
# all_recall_score_fcg mean 0.11892735185745938
# all_precision_score_fcg mean 0.12065654265614836
# all_f1_score_fcg mean 0.10752351239015728
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 0.32850658893585205
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  30.0  0.153333  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg  30.0  0.118667  0.018889  0.003449   0.111614
# 2                     combined  60.0  0.136000  0.021930  0.002831   0.130335
#
#    Interval
# 0       NaN
# 1  0.125720
# 2  0.141665
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.0347
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   10.0524
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.5955
# 7                                       Hedge's g =    2.5618
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7971
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 0.24380600452423096
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline  30.0  0.162521  0.000000  0.000000        NaN
# 1       all_recall_score_fcg  30.0  0.118927  0.018707  0.003415   0.111942
# 2                   combined  60.0  0.140724  0.025596  0.003304   0.134112
#
#    Interval
# 0       NaN
# 1  0.125913
# 2  0.147336
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.0436
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   12.7634
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    3.2955
# 7                                       Hedge's g =    3.2527
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.8587
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 0.9414968490600586
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.156858  2.823006e-17  5.154081e-18
# 1       all_precision_score_fcg  30.0  0.120657  2.290883e-02  4.182561e-03
# 2                      combined  60.0  0.138757  2.431369e-02  3.138884e-03
#
#    95% Conf.  Interval
# 0   0.156858  0.156858
# 1   0.112102  0.129211
# 2   0.132477  0.145038
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all...  3.620000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   8.655400e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   2.234800e+00
# 7                                       Hedge's g =   2.205800e+00
# 8                                  Glass's delta1 =   1.282385e+15
# 9                                Point-Biserial r =   7.508000e-01
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 0.3297767639160156
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.138225  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  30.0  0.107524  0.018959  0.003461   0.100444
# 2               combined  60.0  0.122874  0.020404  0.002634   0.117604
#
#    Interval
# 0       NaN
# 1  0.114603
# 2  0.128145
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0307
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    8.8697
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.2901
# 7                                       Hedge's g =    2.2604
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7587
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment_M
scope_num = 3
topology_ratio =4


dic=  {3: 606, 2: 151, 5: 26, 8: 684, 6: 134, 7: 534, 4: 253, 1: 609, 9: 519}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.16666666666666666
# recall_score_fcg 0.16693117660859597
# precision_score_fcg 0.1616363255526344
# f1_score_fcg 0.1458660560600573
# Experiment number: 2
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.16666666666666666
# recall_score_fcg 0.16693117660859597
# precision_score_fcg 0.1616363255526344
# f1_score_fcg 0.1458660560600573
# Experiment number: 3
# accuracy_score_baseline 0.15333333333333332
# recall_score_baseline 0.1625205738108964
# precision_score_baseline 0.15685835103257972
# f1_score_baseline 0.13822544173607637
# accuracy_score_fcg 0.16666666666666666
# recall_score_fcg 0.16693117660859597
# precision_score_fcg 0.1616363255526344
# f1_score_fcg 0.1458660560600573
# max_accuracy_score_fcg 0.16666666666666666
# max_recall_score_fcg 0.16693117660859597
# max_precision_score_fcg 0.1616363255526344
# max_f1_score_fcg 0.1458660560600573
# all_accuracy_score_baseline mean 0.15333333333333332
# all_recall_score_baseline mean 0.1625205738108964
# all_precision_score_baseline mean 0.15685835103257972
# all_f1_score_baseline mean 0.13822544173607637
# all_accuracy_score_fcg mean 0.16666666666666666
# all_recall_score_fcg mean 0.166931176608596
# all_precision_score_fcg mean 0.1616363255526344
# all_f1_score_fcg mean 0.1458660560600573
# len plot_unit 3  len (all_test_score_baseline_accuracy) 3
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 1.0
# Accuracy Score T-Test
#                       Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  3.0  0.153333  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg  3.0  0.166667  0.000000  0.000000        NaN
# 2                     combined  6.0  0.160000  0.007303  0.002981   0.152336
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.167664
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0133
# 1                              Degrees of freedom =    4.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 1.0
# Recall Score T-Test
#                     Variable    N      Mean            SD            SE  \
# 0  all_recall_score_baseline  3.0  0.162521  0.000000e+00  0.000000e+00
# 1       all_recall_score_fcg  3.0  0.166931  3.399350e-17  1.962616e-17
# 2                   combined  6.0  0.164726  2.415787e-03  9.862408e-04
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.166931  0.166931
# 2   0.162191  0.167261
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -4.400000e-03
# 1                              Degrees of freedom =   4.000000e+00
# 2                                               t =  -2.247309e+14
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.834920e+14
# 7                                       Hedge's g =  -1.467936e+14
# 8                                  Glass's delta1 =           -inf
# 9                                Point-Biserial r =  -1.000000e+00
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 1.0
# Precision Score T-Test
#                        Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_precision_score_baseline  3.0  0.156858  0.000000  0.000000        NaN
# 1       all_precision_score_fcg  3.0  0.161636  0.000000  0.000000        NaN
# 2                      combined  6.0  0.159247  0.002617  0.001068   0.156501
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.161994
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0048
# 1                              Degrees of freedom =    4.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 1.0
# F1 Score T-Test
#                 Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  3.0  0.138225  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  3.0  0.145866  0.000000  0.000000        NaN
# 2               combined  6.0  0.142046  0.004185  0.001708   0.137654
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.146438
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0076
# 1                              Degrees of freedom =    4.0000
# 2                                               t =      -inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =      -inf
# 7                                       Hedge's g =      -inf
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
