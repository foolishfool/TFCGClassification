# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])


dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)




dataread.initializedataset(csv,csv_training,csv_test,"Subscription Type")

#dataread.data_train_discrete
# Out:
# continuous_feature_num 3
# discrete_feature_num 4
# self.data_discrete_indexes ['Monthly Revenue', 'Country', 'Gender', 'Device']

# %%
import experiment
scope_num = 30
topology_ratio = 3

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio,nfolder =0)
# Out:
# Experiment number: 1
# self.random_dic {0: 1594, 2: 198, 1: 1600}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.44266666666666665
# recall_score_fcg 0.4397872484580873
# precision_score_fcg 0.5581902439184941
# f1_score_fcg 0.46493440909643935
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# self.random_dic {0: 873, 2: 163, 1: 1525}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.44266666666666665
# recall_score_fcg 0.4397872484580873
# precision_score_fcg 0.5581902439184941
# f1_score_fcg 0.46493440909643935
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# self.random_dic {0: 465, 2: 783, 1: 179}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 4
# self.random_dic {0: 654, 2: 1034, 1: 292}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 5
# self.random_dic {0: 588, 2: 572, 1: 389}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.44266666666666665
# recall_score_fcg 0.4397872484580873
# precision_score_fcg 0.5581902439184941
# f1_score_fcg 0.46493440909643935
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# self.random_dic {0: 219, 2: 636, 1: 912}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 7
# self.random_dic {0: 393, 2: 152, 1: 1278}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.284
# recall_score_fcg 0.32970967724353634
# precision_score_fcg 0.16864521242158373
# f1_score_fcg 0.21548317339418008
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# self.random_dic {0: 41, 2: 984, 1: 532}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.228
# recall_score_fcg 0.19676258481145895
# precision_score_fcg 0.1653188779288486
# f1_score_fcg 0.179668586202844
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# self.random_dic {0: 544, 2: 997, 1: 404}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.44266666666666665
# recall_score_fcg 0.4397872484580873
# precision_score_fcg 0.5581902439184941
# f1_score_fcg 0.46493440909643935
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# self.random_dic {0: 298, 2: 783, 1: 374}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 11
# self.random_dic {0: 1672, 2: 1205, 1: 964}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.532
# recall_score_fcg 0.5332959295950067
# precision_score_fcg 0.6415556674598708
# f1_score_fcg 0.5453158208113985
# Not good accuracy result !!!!!
# Experiment number: 12
# self.random_dic {0: 942, 2: 1461, 1: 528}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.532
# recall_score_fcg 0.5332959295950067
# precision_score_fcg 0.6415556674598708
# f1_score_fcg 0.5453158208113985
# Not good accuracy result !!!!!
# Experiment number: 13
# self.random_dic {0: 1494, 2: 776, 1: 524}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.24
# recall_score_fcg 0.2699414855935343
# precision_score_fcg 0.1931254546112806
# f1_score_fcg 0.2228851098709844
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# self.random_dic {0: 823, 2: 811, 1: 1734}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 15
# self.random_dic {0: 1232, 2: 796, 1: 326}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.24
# recall_score_fcg 0.2699414855935343
# precision_score_fcg 0.1931254546112806
# f1_score_fcg 0.2228851098709844
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# self.random_dic {0: 1635, 2: 673, 1: 1539}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.532
# recall_score_fcg 0.5332959295950067
# precision_score_fcg 0.6415556674598708
# f1_score_fcg 0.5453158208113985
# Not good accuracy result !!!!!
# Experiment number: 17
# self.random_dic {0: 494, 2: 741, 1: 10}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 18
# self.random_dic {0: 1478, 2: 488, 1: 1599}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.532
# recall_score_fcg 0.5332959295950067
# precision_score_fcg 0.6415556674598708
# f1_score_fcg 0.5453158208113985
# Not good accuracy result !!!!!
# Experiment number: 19
# self.random_dic {0: 203, 2: 1264, 1: 560}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.24
# recall_score_fcg 0.2699414855935343
# precision_score_fcg 0.1931254546112806
# f1_score_fcg 0.2228851098709844
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# self.random_dic {0: 439, 2: 1169, 1: 1370}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.44266666666666665
# recall_score_fcg 0.4397872484580873
# precision_score_fcg 0.5581902439184941
# f1_score_fcg 0.46493440909643935
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# self.random_dic {0: 147, 2: 483, 1: 1668}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 22
# self.random_dic {0: 349, 2: 620, 1: 519}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.376
# recall_score_fcg 0.3519966510781569
# precision_score_fcg 0.4688623222378497
# f1_score_fcg 0.3724104336315519
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# self.random_dic {0: 658, 2: 426, 1: 1450}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.20666666666666667
# recall_score_fcg 0.23548992183943618
# precision_score_fcg 0.17447465195692144
# f1_score_fcg 0.19845903137166665
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# self.random_dic {0: 70, 2: 1398, 1: 726}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 25
# self.random_dic {0: 1510, 2: 1638, 1: 108}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.24
# recall_score_fcg 0.2699414855935343
# precision_score_fcg 0.1931254546112806
# f1_score_fcg 0.2228851098709844
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# self.random_dic {0: 1023, 2: 755, 1: 85}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.284
# recall_score_fcg 0.32970967724353634
# precision_score_fcg 0.16864521242158373
# f1_score_fcg 0.21548317339418008
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# self.random_dic {0: 819, 2: 1428, 1: 1552}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.24
# recall_score_fcg 0.2699414855935343
# precision_score_fcg 0.1931254546112806
# f1_score_fcg 0.2228851098709844
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# self.random_dic {0: 877, 2: 656, 1: 1513}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.24
# recall_score_fcg 0.2699414855935343
# precision_score_fcg 0.1931254546112806
# f1_score_fcg 0.2228851098709844
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# self.random_dic {0: 863, 2: 1215, 1: 1203}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 30
# self.random_dic {0: 1263, 2: 1429, 1: 685}
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.548
# recall_score_fcg 0.5345288438389715
# precision_score_fcg 0.6362030470186498
# f1_score_fcg 0.5503778693595673
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.5986666666666667
# max_recall_score_fcg 0.621086526974937
# max_precision_score_fcg 0.7515376286473333
# max_f1_score_fcg 0.6041935768964887
# all_accuracy_score_baseline mean 0.5626666666666666
# all_recall_score_baseline mean 0.528541653456159
# all_precision_score_baseline mean 0.5283442632227094
# all_f1_score_baseline mean 0.5052626665571062
# all_accuracy_score_fcg mean 0.4365333333333334
# all_recall_score_fcg mean 0.45065816576870665
# all_precision_score_fcg mean 0.5020638199637025
# all_f1_score_fcg mean 0.4337623482458695
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 0.0002179896691814065
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  30.0  0.562667  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg  30.0  0.436533  0.151308  0.027625   0.380034
# 2                     combined  60.0  0.499600  0.123684  0.015968   0.467649
#
#    Interval
# 0       NaN
# 1  0.493033
# 2  0.531551
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.1261
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    4.5659
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    1.1789
# 7                                       Hedge's g =    1.1636
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.5142
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 0.0013749494682997465
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline  30.0  0.528542  0.000000  0.000000        NaN
# 1       all_recall_score_fcg  30.0  0.450658  0.148795  0.027166   0.395097
# 2                   combined  60.0  0.489600  0.111465  0.014390   0.460805
#
#    Interval
# 0       NaN
# 1  0.506219
# 2  0.518394
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.0779
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    2.8669
# 3                           Two side test p value =    0.0058
# 4                          Difference < 0 p value =    0.9971
# 5                          Difference > 0 p value =    0.0029
# 6                                       Cohen's d =    0.7402
# 7                                       Hedge's g =    0.7306
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.3523
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 4.311144584789872e-05
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.528344  2.258405e-16  4.123265e-17
# 1       all_precision_score_fcg  30.0  0.502064  2.412981e-01  4.405480e-02
# 2                      combined  60.0  0.515204  1.696896e-01  2.190683e-02
#
#    95% Conf.  Interval
# 0   0.528344  0.528344
# 1   0.411962  0.592166
# 2   0.471369  0.559040
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all...  2.630000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   5.965000e-01
# 3                           Two side test p value =   5.531000e-01
# 4                          Difference < 0 p value =   7.234000e-01
# 5                          Difference > 0 p value =   2.766000e-01
# 6                                       Cohen's d =   1.540000e-01
# 7                                       Hedge's g =   1.520000e-01
# 8                                  Glass's delta1 =   1.163673e+14
# 9                                Point-Biserial r =   7.810000e-02
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 5.7156470575137064e-05
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.505263  1.129203e-16  2.061632e-17
# 1       all_f1_score_fcg  30.0  0.433762  1.676879e-01  3.061548e-02
# 2               combined  60.0  0.469513  1.229677e-01  1.587506e-02
#
#    95% Conf.  Interval
# 0   0.505263  0.505263
# 1   0.371147  0.496378
# 2   0.437747  0.501278
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  7.150000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.335400e+00
# 3                           Two side test p value =   2.300000e-02
# 4                          Difference < 0 p value =   9.885000e-01
# 5                          Difference > 0 p value =   1.150000e-02
# 6                                       Cohen's d =   6.030000e-01
# 7                                       Hedge's g =   5.952000e-01
# 8                                  Glass's delta1 =   6.331930e+14
# 9                                Point-Biserial r =   2.932000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment_M
scope_num =2
topology_ratio =3


dic=   {0: 465, 2: 783, 1: 179}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# Experiment number: 2
# accuracy_score_baseline 0.5626666666666666
# recall_score_baseline 0.528541653456159
# precision_score_baseline 0.5283442632227092
# f1_score_baseline 0.505262666557106
# accuracy_score_fcg 0.5986666666666667
# recall_score_fcg 0.621086526974937
# precision_score_fcg 0.7515376286473333
# f1_score_fcg 0.6041935768964887
# max_accuracy_score_fcg 0.5986666666666667
# max_recall_score_fcg 0.621086526974937
# max_precision_score_fcg 0.7515376286473333
# max_f1_score_fcg 0.6041935768964887
# all_accuracy_score_baseline mean 0.5626666666666666
# all_recall_score_baseline mean 0.528541653456159
# all_precision_score_baseline mean 0.5283442632227092
# all_f1_score_baseline mean 0.505262666557106
# all_accuracy_score_fcg mean 0.5986666666666667
# all_recall_score_fcg mean 0.621086526974937
# all_precision_score_fcg mean 0.7515376286473333
# all_f1_score_fcg mean 0.6041935768964887
# len plot_unit 2  len (all_test_score_baseline_accuracy) 2
# Normal test + all_test_score_baseline_accuracy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       7 #print(experiment.train_new_embedding_fcg_fuzzy)
#       8 experiment_M = experiment_M.Experiment()
# ----> 9 experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
#
# File C:\JupyterDoc\FCG\VersionStore\Version2FCGClassification TFCG_TineTuneComparision\experiment_M.py:268, in Experiment.Ttest(self, dataread, scope_num, topology_ratio, nfolder, dic, class_num, class_index_group_dic, all_features_mapping_fuzzy, train_new_embedding_fcg_fuzzy, test_new_embedding_fcg_fuzzy)
#     265 plt.show()
#     267 print(f"Normal test + all_test_score_baseline_accuracy")
# --> 268 shapiro_test = stats.shapiro(all_test_score_baseline_accuracy)
#     269 print(shapiro_test.pvalue)
#     270 print(f"Normal test + all_test_score_fcg_accuracy")
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1869, in shapiro(x)
#    1867 N = len(x)
#    1868 if N < 3:
# -> 1869     raise ValueError("Data must be at least length 3.")
#    1871 x = x - np.median(x)
#    1873 a = zeros(N, 'f')
#
# ValueError: Data must be at least length 3.
