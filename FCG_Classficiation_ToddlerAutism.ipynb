# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")
csv = csv.sample(int(csv.shape[0]))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Ethnicity")
dataread.label_encoding(csv,"Jaundice")
dataread.label_encoding(csv,"Family_mem_with_ASD")
dataread.label_encoding(csv,"Who completed the test")
dataread.label_encoding(csv,"Class/ASD Traits ")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Class/ASD Traits ")
# Out:
# continuous_feature_num 2
# discrete_feature_num 16
# self.data_discrete_indexes ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'Qchat-10-Score', 'Sex', 'Ethnicity', 'Jaundice', 'Family_mem_with_ASD', 'Who completed the test']

# %%
import experiment
scope_num = 3
topology_ratio =2
experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# self.random_dic {1: 437, 0: 706}
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 0.9240506329113924
# recall_score_fcg 0.9489361702127659
# precision_score_fcg 0.8857142857142857
# f1_score_fcg 0.9085780413713295
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# self.random_dic {1: 155, 0: 33}
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 0.9240506329113924
# recall_score_fcg 0.9489361702127659
# precision_score_fcg 0.8857142857142857
# f1_score_fcg 0.9085780413713295
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# self.random_dic {1: 495, 0: 65}
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 0.9240506329113924
# recall_score_fcg 0.9489361702127659
# precision_score_fcg 0.8857142857142857
# f1_score_fcg 0.9085780413713295
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.9240506329113924
# max_recall_score_fcg 0.9489361702127659
# max_precision_score_fcg 0.8857142857142857
# max_f1_score_fcg 0.9085780413713295
# all_accuracy_score_baseline mean 1.0
# all_recall_score_baseline mean 1.0
# all_precision_score_baseline mean 1.0
# all_f1_score_baseline mean 1.0
# all_accuracy_score_fcg mean 0.9240506329113924
# all_recall_score_fcg mean 0.9489361702127659
# all_precision_score_fcg mean 0.8857142857142857
# all_f1_score_fcg mean 0.9085780413713295
# len plot_unit 3  len (all_test_score_baseline_accuracy) 3
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 1.0
# Accuracy Score T-Test
#                       Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg  3.0  0.924051  0.000000  0.000000        NaN
# 2                     combined  6.0  0.962025  0.041599  0.016983    0.91837
#
#    Interval
# 0       NaN
# 1       NaN
# 2  1.005681
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.0759
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 1.0
# Recall Score T-Test
#                     Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_recall_score_fcg  3.0  0.948936  0.000000  0.000000        NaN
# 2                   combined  6.0  0.974468  0.027969  0.011418   0.945117
#
#    Interval
# 0       NaN
# 1       NaN
# 2   1.00382
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.0511
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 1.0
# Precision Score T-Test
#                        Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_precision_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_precision_score_fcg  3.0  0.885714  0.000000  0.000000        NaN
# 2                      combined  6.0  0.942857  0.062597  0.025555   0.877166
#
#    Interval
# 0       NaN
# 1       NaN
# 2  1.008549
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...   0.1143
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 1.0
# F1 Score T-Test
#                 Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  3.0  0.908578  0.000000  0.000000        NaN
# 2               combined  6.0  0.954289  0.050074  0.020443    0.90174
#
#    Interval
# 0       NaN
# 1       NaN
# 2  1.006838
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0914
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment_M
scope_num = 3
topology_ratio =2

dic={1: 495, 0: 65}
#print(experiment.train_new_embedding_fcg_fuzzy)
experiment_M = experiment_M.Experiment()
experiment_M.Ttest(dataread,scope_num,topology_ratio,0,dic,experiment.class_num,experiment.class_index_group_dic,experiment.all_features_mapping_fuzzy,experiment.train_new_embedding_fcg_fuzzy,experiment.test_new_embedding_fcg_fuzzy)
# Out:
# Experiment number: 1
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 0.9240506329113924
# recall_score_fcg 0.9489361702127659
# precision_score_fcg 0.8857142857142857
# f1_score_fcg 0.9085780413713295
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 0.9240506329113924
# recall_score_fcg 0.9489361702127659
# precision_score_fcg 0.8857142857142857
# f1_score_fcg 0.9085780413713295
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 0.9240506329113924
# recall_score_fcg 0.9489361702127659
# precision_score_fcg 0.8857142857142857
# f1_score_fcg 0.9085780413713295
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# max_accuracy_score_fcg 0.9240506329113924
# max_recall_score_fcg 0.9489361702127659
# max_precision_score_fcg 0.8857142857142857
# max_f1_score_fcg 0.9085780413713295
# all_accuracy_score_baseline mean 1.0
# all_recall_score_baseline mean 1.0
# all_precision_score_baseline mean 1.0
# all_f1_score_baseline mean 1.0
# all_accuracy_score_fcg mean 0.9240506329113924
# all_recall_score_fcg mean 0.9489361702127659
# all_precision_score_fcg mean 0.8857142857142857
# all_f1_score_fcg mean 0.9085780413713295
# len plot_unit 3  len (all_test_score_baseline_accuracy) 3
# Normal test + all_test_score_baseline_accuracy
# 1.0
# Normal test + all_test_score_fcg_accuracy
# 1.0
# Accuracy Score T-Test
#                       Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_accuracy_score_fcg  3.0  0.924051  0.000000  0.000000        NaN
# 2                     combined  6.0  0.962025  0.041599  0.016983    0.91837
#
#    Interval
# 0       NaN
# 1       NaN
# 2  1.005681
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.0759
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_recall
# 1.0
# Normal test + all_test_score_fcg_recall
# 1.0
# Recall Score T-Test
#                     Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_recall_score_fcg  3.0  0.948936  0.000000  0.000000        NaN
# 2                   combined  6.0  0.974468  0.027969  0.011418   0.945117
#
#    Interval
# 0       NaN
# 1       NaN
# 2   1.00382
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.0511
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_precision
# 1.0
# Normal test + all_test_score_fcg_precision
# 1.0
# Precision Score T-Test
#                        Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_precision_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_precision_score_fcg  3.0  0.885714  0.000000  0.000000        NaN
# 2                      combined  6.0  0.942857  0.062597  0.025555   0.877166
#
#    Interval
# 0       NaN
# 1       NaN
# 2  1.008549
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...   0.1143
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# Normal test + all_test_score_baseline_f1
# 1.0
# Normal test + all_test_score_fcg_f1
# 1.0
# F1 Score T-Test
#                 Variable    N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  3.0  1.000000  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  3.0  0.908578  0.000000  0.000000        NaN
# 2               combined  6.0  0.954289  0.050074  0.020443    0.90174
#
#    Interval
# 0       NaN
# 1       NaN
# 2  1.006838
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.0914
# 1                              Degrees of freedom =    4.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_morestats.py:1879: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
